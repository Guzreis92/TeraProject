# %%
#Importando bibliotecas:
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import missingno as msno

# %%
#importando dataframe:
consumo = pd.read_csv('data/CONSUMO_ALIMENTAR.csv')

# %%
#Aumentando o número de exibições por coluna e linha:
pd.options.display.max_columns = 100
pd.options.display.max_rows = 200

# %%
#Criando coluna PESSOA:
consumo['Família'] = consumo.COD_UPA.astype(str) + consumo.NUM_DOM.astype(str)

# %%
#Tratando valores nulos:
# pd.options.mode.chained_assignment = None
# df_consumo.loc[pd.isnull(df_consumo.V9005),'V9005']= 0
# df_consumo.loc[pd.isnull(df_consumo.V9007),'V9007']= 0
# df_consumo.loc[pd.isnull(df_consumo.V9016),'V9016']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9019),'V9019']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9020),'V9020']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9021),'V9021']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9022),'V9022']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9023),'V9023']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9024),'V9024']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9025),'V9025']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9026),'V9026']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9027),'V9027']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9028),'V9028']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9029),'V9029']= 99
# df_consumo.loc[pd.isnull(df_consumo.V9030),'V9030']= 99
# df_consumo.loc[pd.isnull(df_consumo.COD_UNIDADE_MEDIDA_FINAL),'COD_UNIDADE_MEDIDA_FINAL']= 0
# df_consumo.loc[pd.isnull(df_consumo.COD_PREPARACAO_FINAL),'COD_PREPARACAO_FINAL']= 0
# df_consumo.loc[pd.isnull(df_consumo.GRAMATURA1),'GRAMATURA1']= 0
# df_consumo.fillna(0)

# %%
consumo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1175390 entries, 0 to 1175389
# Data columns (total 68 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UF                        1175390 non-null  int64
#  1   ESTRATO_POF               1175390 non-null  int64
#  2   TIPO_SITUACAO_REG         1175390 non-null  int64
#  3   COD_UPA                   1175390 non-null  int64
#  4   NUM_DOM                   1175390 non-null  int64
#  5   NUM_UC                    1175390 non-null  int64
#  6   COD_INFORMANTE            1175390 non-null  int64
#  7   QUADRO                    1175390 non-null  int64
#  8   SEQ                       1175390 non-null  int64
#  9   V9005                     1007126 non-null  float64
#  10  V9007                     1007126 non-null  float64
#  11  V9001                     1175390 non-null  int64
#  12  V9015                     1175390 non-null  object
# ...

# %%
#hora = consumo.query('V9015 == "1H"')
#hora['V9001'].value_counts()[:50]

# %%
#Criando dicionários para colunas categóricas:
col_V9015 = {'8H': 'Café da manhã',
             '12H': 'Almoço',
             '14H': 'Almoço',
             '20H': 'Jantar',
             '22H': 'Jantar',
             '19H': 'Jantar',
             '7H': 'Café da manhã',
             '16H': 'Lanche',
             '21H': 'Jantar',
             '13H': 'Almoço',
             '17H': 'Lanche',
             '9H': 'Café da manhã',
             '15H': 'Lanche',
             '10H': 'Café da manhã',
             '11H': 'Almoço',
             '18H': 'Jantar',
             '6H': 'Almoço',
             '23H': 'Jantar',
             '0H': 'Lanche',
             '5H': 'Café da manhã',
             '3H': 'Lanche',
             '2H': 'Lanche',
             '4H': 'Café da manhã',
             '1H': 'Lanche'}

col_V9016 = {1: 'Assado(a)', 
              2 : 'Cozido com gordura',
              3 : 'Cozido sem gordura',
              4 : 'Cru',
              5 : 'Empanado',
              6 : 'Ensopado',
              7 : 'Frito',
              8 : 'Grelhado',
              9 : 'Refogado',
              99 : 'Não determinado'}

col_V9017 = {1 : 'Café da manhã',
              2 : 'Almoço',
              3 : 'Lanche',
              4 : 'Jantar',
              5 : 'Ceia',
              6 : 'Outra ocasião',
              9 : 'Não determinado'}

col_V9018 = {1 : 'Em casa ou levado de casa',
              2 : 'Merenda escolar',
              3 : 'Restaurante à quilo',
              4 : 'Cantina, bar, lanchonete, fast food',
              5 : 'Restaurante – outros',
              6 : 'Vendedores ambulantes ou de rua',
              7 : 'Fora de casa – outros',
              9 : 'Não determinado'}

col_PrepFinal = {1 : 'Assado(a)', 
                  2 : 'Cozido com gordura',
                  3 : 'Cozido sem gordura',
                  4 : 'Cru',
                  5 : 'Empanado',
                  6 : 'Ensopado',
                  7 : 'Frito',
                  8 : 'Grelhado',
                  9 : 'Refogado',
                  99 : 'Não aplicável'}

col_V9019 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9020 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9021 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9022 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9023 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9024 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9025 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9026 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9027 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9028 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9029 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9030 = {1: 'Sim',
             2 : 'Não',
             99 : 'Não aplicável'}

col_V9001 = { 6300101: 'ARROZ',
6300113: 'ARROZ BRANCO',
6300201: 'ARROZ INTEGRAL',
6300211: 'ARROZ 3 GRAOS',
6300212: 'ARROZ 7 GRAOS',
6300706: 'CANJIQUINHA DE MILHO EM GRAO',
6300707: 'XEREM DE MILHO',
6300901: 'TRIGO EM GRAO',
6301001: 'AMENDOIM (EM GRAO) (IN NATURA)',
6301101: 'ERVILHA EM GRAO',
6301201: 'FAVA EM GRAO',
6301204: 'MANGALO AMARGO EM GRAO',
6301214: 'MANGALO',
6301603: 'FEIJAO DE CORDA',
6301634: 'FEIJAO VERDE',
6302001: 'SEMENTE DE LINHACA',
6302002: 'LINHACA',
6302011: 'SEMENTES NAO ESPECIFICADAS',
6302602: 'ANDU',
6302801: 'GRAO DE BICO',
6302901: 'LENTILHA',
6303001: 'SOJA EM GRAO',
6303102: 'FEIJAO PRETO',
6303201: 'SEMENTES DE ABOBORA',
6303501: 'QUIRERA',
6304201: 'PIPOCA  LIGHT',
6304901: 'QUINOA',
6305001: 'CHIA',
6380001: 'SEMENTES DE GIRASSOL',
6400101: 'BATATA INGLESA',
6400303: 'MANDIOQUINHA SALSA (BATATA BAROA)',
6400304: 'CENOURA AMARELA (BATATA BAROA)',
6400401: 'BATATA DOCE',
6400501: 'INHAME',
6400508: 'QUICARE',
6400601: 'MANDIOCA',
6400609: 'AIPIM',
6400610: 'MACAXEIRA',
6400701: 'CARA',
6400713: 'INHAME CARAQUENTO (CARA)',
6400802: 'BATATA (NAO ESPECIFICADA)',
6400908: 'MANDIOQUINHA',
6401001: 'RABANETE',
6401101: 'BETERRABA',
6401201: 'CENOURA',
6401301: 'NABO',
6401601: 'ACAFRAO',
6480001: 'GENGIBRE',
6500101: 'CREME DE ARROZ',
6500104: 'ARROZINA',
6500105: 'MUCILON',
6500108: 'MINGAU DE ARROZ',
6500201: 'FLOCOS DE ARROZ',
6500202: 'CROQUINHOS DE ARROZ',
6500301: 'FARINHA DE AVEIA',
6500401: 'AVEIA EM FLOCOS',
6500603: 'FARINHA DE MILHO',
6500614: 'MINGAU DE MILHO',
6500615: 'MINGAU DE CHOCOLATE',
6500616: 'MINGAU DE MAIZENA',
6500617: 'MINGAU DE NESTON',
6500801: 'CREMOGEMA',
6500802: 'VITAMILHO',
6500804: 'CREME DE MILHO',
6500902: 'SUCRILHOS DE MILHO',
6500903: 'CEREAL MATINAL DE MILHO EM FLOCOS',
6501301: 'GERME DE TRIGO',
6501303: 'FIBRA DE TRIGO',
6501304: 'FIBRA DE CEREAL TRIGO',
6501401: 'FARINHA DE MANDIOCA',
6501410: 'FARINHA DE COPIOBA',
6501415: 'FARINHA DE AGUA',
6501416: 'CRUERA/ CRUEIRA',
6501515: 'SAGU DE TAPIOCA',
6501516: 'TAPIOCA DE GOMA',
6502001: 'FARINHA LACTEA',
6502101: 'NESTON',
6502102: 'FLOCOS DE CEREAIS',
6502105: 'VITAFLOCOS',
6502106: 'FLOCOS NAO ESPECIFICADO',
6502107: 'FLOCOS DE CENTEIO',
6502108: 'FLOCOS DE CEVADA',
6502109: 'FLOCOS DE TRIGO',
6502501: 'FIBRA DE SOJA',
6502603: 'MINI PASTEL',
6503401: 'MACARRAO',
6503501: 'PURE DE BATATA',
6503502: 'PURE DE ABOBORA / JERIMUM / GERIMUM',
6503503: 'PURE DE INHAME',
6503504: 'PURE DE MANDIOCA',
6503601: 'BIFE VEGETAL',
6503603: 'CARNE VEGETAL',
6503604: 'PASTA DE SOJA',
6503605: 'CARNE DE SOJA',
6503702: 'AMENDOIM MOIDO',
6504101: 'GRANOLA',
6504601: 'MUSLI',
6504701: 'MIX DE CEREAIS',
6504801: 'MIOJO',
6504802: 'MACARRAO INSTANTANEO',
6505101: 'SUSTAGEM',
6505102: 'NUTREN, ENSURE, SUSTEN',
6505601: 'PROTEINA DE SOJA',
6505603: 'PROTEINA VEGETAL',
6505701: 'COMPLEMENTO ALIMENTAR DE QUALQUER SABOR',
6505902: 'SUCRILHOS DE MILHO LIGHT',
6506302: 'MACARRAO INSTANTANEO LIGHT',
6573225: 'MACARRAO COM CARNE',
6573226: 'MACARRAO COM PEIXE / ATUM / SARDINHA',
6573239: 'MACARRONESE',
6573240: 'SALADA DE MACARRAO',
6573241: 'SALADA DE MACARRAO COM MAIONESE',
6573242: 'MASSA / MACARRAO INTEGRAL',
6573243: 'MASSA / MACARRAO SEM GLUTEN',
6573244: 'MASSA, ARROZ (TIPO BIFUM)',
6580001: 'SUPLEMENTO PROTEICO E OUTROS',
6580101: 'VITAMINAS, MINERAIS E OUTROS',
6580201: 'ALETRIA',
6600101: 'COCO DA BAHIA',
6600104: 'COCO SECO',
6600105: 'COCO VERDE',
6600301: 'CASTANHA PORTUGUESA',
6600401: 'PINHAO',
6600501: 'AMENDOA',
6600601: 'AVELA',
6600701: 'CASTANHA DO PARA',
6600702: 'CASTANHA DO BRASIL',
6600703: 'NOZES DO PARA',
6600801: 'CASTANHA DE CAJU',
6600901: 'COCO OURICURI',
6600912: 'BUTIA',
6600913: 'LICURI',
6601002: 'COCO BABACU',
6601005: 'BABACU / BABASSU',
6601108: 'TUCUMA',
6601208: 'COCO MUCAJA',
6601211: 'MACAUBA',
6601213: 'BOCAIUVA',
6601501: 'NOZ',
6601601: 'COCO-INAJA',
6601602: 'COCO-ANAJA',
6601604: 'COCOANAIA',
6601605: 'INAJA',
6601607: 'NAJA',
6601707: 'JUCARA',
6601709: 'UACAI',
6601712: 'JUSSARA',
6601803: 'COCO PUPUNHA',
6601805: 'PUPUNHA',
6601902: 'BACABA',
6601904: 'BACABUCU',
6602001: 'CASTANHA DA INDIA',
6602201: 'PISTACHE',
6602301: 'BURITI',
6602401: 'COCO NAO ESPECIFICADO',
6602501: 'CASTANHAS NAO ESPECIFICADAS',
6602502: 'CASTANHAS E SEMENTES, MISTURA',
6602601: 'PATAUA',
6602901: 'NOZ MACADAMIA',
6603001: 'NOZ PECAN',
6603002: 'PECAN',
6603102: 'SAPUCAIA',
6603201: 'TAHINI, PASTA',
6700101: 'ALFACE',
6700201: 'BERTALHA',
6700301: 'CHICORIA',
6700304: 'ESCAROLA',
6700305: 'ENDIVIA',
6700501: 'COUVE',
6700601: 'COUVE FLOR',
6700701: 'ESPINAFRE',
6700801: 'MOSTARDA (VERDURA)',
6700901: 'REPOLHO',
6700903: 'REPOLHO ROXO',
6700904: 'REPOLHO VERDE',
6701101: 'CEBOLINHA',
6701301: 'AGRIAO',
6701401: 'TAIOBA',
6701501: 'ACELGA',
6701505: 'BETERRABA BRANCA (ACELGA)',
6701601: 'ALMEIRAO',
6701602: 'RADITE',
6701704: 'BROCOLIS',
6701801: 'SERRALHA',
6701901: 'CARURU',
6701904: 'AZEDA',
6701906: 'CUXA',
6701907: 'VINAGREIRA',
6701913: 'CARIRU',
6702001: 'RUCULA',
6702105: 'JAMBU',
6702201: 'LINGUA DE VACA (VERDURA)',
6702301: 'ALCACHOFRA',
6702501: 'BREDO',
6702604: 'SALSAO (AIPO)',
6702701: 'COUVE CHINESA',
6702801: 'ERVA DOCE',
6702901: 'AZEDINHA',
6703001: 'FOLHA DE MANDIOCA',
6703002: 'FOLHA DE MANIVA (MANDIOCA BRAVA)',
6703003: 'FOLHA DE AIPIM',
6703004: 'FOLHA DE MACAXEIRA',
6703101: 'BROTO DE FEIJAO',
6703306: 'MORANGA',
6703701: 'ABOBRINHA',
6703707: 'CAXI',
6703805: 'JERIMUM',
6703901: 'ABOBORA',
6704001: 'PEPINO',
6704101: 'CHUCHU',
6704106: 'CHUCHU AO FORNO',
6704201: 'JILO',
6704301: 'MAXIXE',
6704306: 'PEPININHO (MAXIXE)',
6704401: 'PALMITO IN NATURA',
6704409: 'GUARIROBA (PALMITO IN NATURA)',
6704410: 'GUEROBA / GUEIROBA (PALMITO IN NATURA)',
6704501: 'PIMENTAO',
6704601: 'PIMENTA MALAGUETA',
6705001: 'QUIABO',
6705101: 'TOMATE',
6705201: 'VAGEM',
6705301: 'COGUMELO IN NATURA',
6705401: 'BERINJELA / BERINGELA',
6705501: 'ERVILHA EM VAGEM',
6705601: 'CABACA',
6705701: 'CEBOLA',
6705704: 'CEBOLA ROXA',
6705801: 'CATALONHA',
6705901: 'COUVE-RABANO',
6705907: 'PORONGO / PORUNGO',
6706001: 'NIRA',
6706101: 'JARDINEIRA (SELETA)',
6706102: 'SELETA (JARDINEIRA)',
6706201: 'ALHO',
6706301: 'ALHO PORO',
6707301: 'BROTO DE ALFAFA',
6709301: 'FOLHA DE CENOURA',
6709701: 'OREGANO',
6709901: 'ASPARGOS FRESCO',
6710101: 'MASTRUZ',
6710102: 'MENTRUZ',
6710103: 'MASTRUCO',
6710201: 'COUVE-DE-BRUXELAS',
6710701: 'ORA-PRO-NOBIS',
6711001: 'VEGETAIS FOLHOSOS NAO ESPECIFICADOS',
6711101: 'VEGETAIS NAO ESPECIFICADOS',
6711201: 'ALCAPARRAS',
6711401: 'ALGAS',
6711501: 'ALICHELA',
6711601: 'CAMBUQUIRA',
6711701: 'FLOR NAO ESPECIFICADA',
6711801: 'FLOR DE ABOBORA',
6800701: 'BANANA-ROXA',
6800901: 'BANANA-SAO-TOME',
6801001: 'BANANA DA TERRA',
6801002: 'BANANA-PACOVA',
6801007: 'CHIFRE-DE-BOI',
6801017: 'PACOVA',
6801101: 'BANANA OURO',
6801601: 'MACADAMIA',
6801801: 'LARANJA LIMA',
6801901: 'LIMA',
6802001: 'LIMAO COMUM',
6802201: 'TANGERINA',
6802202: 'MEXERICA',
6802217: 'BERGAMOTA',
6802218: 'MIMOSA',
6802223: 'TANJA',
6802227: 'MARICOTA',
6802305: 'GRAPEFRUIT / TORANJA',
6802407: 'LARANJINHA JAPONESA / QUINCAN / KINKAN',
6802501: 'CANA DE ACUCAR',
6802601: 'ABACAXI',
6802602: 'ANANAS',
6802701: 'ABACATE',
6802801: 'CAQUI',
6802901: 'FIGO',
6803001: 'MACA',
6803101: 'MAMAO',
6803108: 'PAPAIA',
6803201: 'MANGA',
6803215: 'MANGUITO',
6803301: 'MARACUJA',
6803401: 'MELANCIA',
6803501: 'MELAO',
6803601: 'PERA',
6803701: 'PESSEGO',
6803801: 'FRUTA DE CONDE',
6803802: 'PINHA',
6803803: 'ATA',
6803804: 'ANONA',
6803901: 'UVA',
6803912: 'UVA PASSA',
6804001: 'JENIPAPO',
6804101: 'JACA',
6804201: 'GOIABA',
6804203: 'ARACA ACU (GOIABA)',
6804301: 'AMEIXA',
6804401: 'CAJU',
6804501: 'CEREJA',
6804601: 'CAJA MANGA',
6804602: 'CAJARANA',
6804604: 'UMBU-CAJA',
6804701: 'TAPEREBA / TAPERIBA / CAJA-MIRIM / CAJA-PEQUENO',
6804702: 'ACAJA (TAPEREBA)',
6804705: 'CAJA',
6804801: 'CARAMBOLA',
6804908: 'JABUTICABA / JABOTICABA',
6805001: 'GRAVIOLA / JACA-DE-POBRE',
6805101: 'ARATICUM',
6805201: 'MORANGO',
6805301: 'JAMBO',
6805401: 'ATEMOIA',
6805501: 'GROSELHA',
6805601: 'MANGABA',
6805701: 'ARACA',
6805801: 'NESPERA',
6805901: 'FRUTA PAO',
6806001: 'SAPOTI',
6806101: 'UXI',
6806201: 'TAMARINDO',
6806301: 'CACAU (FRUTA)',
6806401: 'PITOMBA',
6806501: 'BACURI',
6806601: 'INGA',
6806701: 'PEQUI',
6806703: 'PEQUIA',
6806704: 'PIQUIA',
6806801: 'PITANGA',
6806901: 'CIRIGUELA',
6806902: 'CERIGUELA / SERIGUELA / SIRIGUELA',
6807001: 'MURICI',
6807015: 'MIRICI',
6807101: 'UMBU',
6807103: 'IMBU',
6807202: 'BIRIBA / BERIBA',
6807301: 'CUPUACU',
6807401: 'NECTARINA',
6807501: 'MARI',
6807505: 'UMARI',
6807601: 'ROMA',
6807701: 'ACEROLA',
6807801: 'KIWI',
6807901: 'MANGOSTIM',
6807902: 'MANGOSTAO',
6808001: 'ABIU',
6808101: 'ABRICO',
6808102: 'ABRICO-DO-PARA',
6808201: 'JURUBEBA',
6808301: 'GRUMIXAMA',
6809901: 'AMORA',
6810001: 'LICHIA',
6810201: 'JAMELAO (JAMBURAO)',
6810301: 'CACARI / CAMU-CAMU',
6810401: 'CAMAPU',
6810402: 'FISALIS',
6810403: 'PHYSALIS',
6810501: 'CRANBERRY',
6810601: 'FRAMBOESA',
6810701: 'MARMELO',
6810801: 'MIRTILO',
6810901: 'TAMARA',
6811001: 'DAMASCO',
6900301: 'ACUCAR DEMERARA',
6900302: 'DEMERARA',
6900304: 'ACUCAR MASCAVO',
6900401: 'RAPADURA',
6900402: 'ALFENIM DE CANA',
6900403: 'BATIDA (RAPADURA)',
6900501: 'SORVETE DE QUALQUER SABOR INDUSTRIALIZADO',
6900502: 'PICOLE DE QUALQUER SABOR INDUSTRIALIZADO',
6900507: 'SORVETE DE PALITO',
6900601: 'CHICLETES',
6900603: 'BALA',
6900604: 'CARAMELO (BALA)',
6900605: 'DROPS',
6900606: 'PASTILHA',
6900607: 'PIRULITO',
6900609: 'GOMA DE MASCAR',
6900610: 'JUJUBA',
6900615: 'BALA DE COCO',
6900616: 'BALA DE GOMA',
6900617: 'BALA DE FRUTA',
6900701: 'TABLETE DE CHOCOLATE',
6900702: 'BARRA DE CHOCOLATE',
6900703: 'CHOCOLATE, TABLETE NAO ESPECIFICADO',
6900706: 'CONFETE',
6900710: 'CHOCOLATE, TABLETE, AO LEITE',
6900711: 'CHOCOLATE, TABLETE, AO LEITE, RECHEADO',
6900712: 'CHOCOLATE, TABLETE, BRANCO',
6900713: 'CHOCOLATE, TABLETE, BRANCO, RECHEADO',
6900714: 'CHOCOLATE, TABLETE, MEIO AMARGO',
6900715: 'CHOCOLATE, TABLETE, MEIO AMARGO, RECHEADO',
6900716: 'CHOCOLATE, TABLETE, RECHEADO NAO ESPECIFICADO',
6900801: 'CHOCOLATE EM PO DE QUALQUER MARCA',
6900818: 'OVOMALTINE',
6900819: 'OVOMALTINE EM PO',
6900821: 'ACHOCOLATADO EM PO',
6900822: 'TODDYNHO',
6900901: 'BOMBOM DE QUALQUER MARCA',
6900904: 'TRUFA',
6901001: 'GELEIA DE FRUTAS DE QUALQUER MARCA OU SABOR',
6901002: 'MOUSSE',
6901101: 'GELEIA DE MOCOTO',
6901201: 'DOCE DE FRUTAS EM PASTA DE QUALQUER SABOR',
6901203: 'PASTA DE AMENDOIM',
6901204: 'PESSEGADA',
6901206: 'MARMELADA',
6901209: 'FIGADA',
6901211: 'GOIABADA',
6901214: 'CAJU EM PASTA',
6901224: 'MARIOLA',
6901231: 'DOCE DE BANANA EM PASTA',
6901240: 'BANANADA',
6901301: 'DOCE DE FRUTAS EM CALDA DE QUALQUER SABOR',
6901401: 'DOCE DE FRUTAS CRISTALIZADO DE QUALQUER SABOR',
6901501: 'MELADO',
6901602: 'MEL',
6901701: 'GELATINA DE QUALQUER SABOR',
6901801: 'ADOCANTE ARTIFICIAL',
6902004: 'MERENGUE',
6902209: 'MARSHMALLOW',
6902301: 'SCHIMIER  / CHIMIA DE CANA',
6902401: 'FRUTA SECA OU DESIDRATADA',
6902402: 'PASSA',
6902601: 'PUDIM DE QUALQUER SABOR',
6902607: 'DANETTE PUDIM',
6902701: 'MANJAR',
6902901: 'CUSCUZ',
6902902: 'CUSCUZ DE TAPIOCA',
6902910: 'CUSCUZ COM LEITE',
6902911: 'CUSCUZ COM LEITE DE COCO',
6903001: 'MARIA MOLE',
6903002: 'BABA DE MOCA',
6903101: 'COCADA',
6903102: 'QUEBRA QUEIXO',
6903201: 'DOCE DE AMENDOIM',
6903202: 'PE DE MOLEQUE',
6903203: 'PACOCA',
6903204: 'TORRAO DE AMENDOIM',
6903205: 'PACOQUINHA DE AMENDOIM',
6903207: 'AMENDOIM CARAMELIZADO',
6903208: 'AMENDOIM AMANTEIGADO',
6903209: 'AMENDOIM ACHOCOLATADO',
6903303: 'AMENDOIM APIMENTADO',
6903304: 'AMENDOIM COZIDO',
6903601: 'BRIGADEIRO',
6903701: 'BOMBA DE QUALQUER TIPO',
6903801: 'MIL FOLHAS',
6903802: 'DOCE DE MASSA FOLHADA',
6903901: 'QUEIJADINHA',
6904101: 'DOCE A BASE DE OVOS',
6904104: 'CACAROLA ITALIANA',
6904105: 'QUINDIM',
6904108: 'FIOS DE OVOS',
6904201: 'DOCE A BASE DE LEITE',
6904202: 'PAVE DE QUALQUER SABOR',
6904203: 'AMBROSIA',
6904204: 'LEITE GELEIFICADO',
6904205: 'CHANDELE DE QUALQUER SABOR',
6904301: 'DOCE DE LEITE',
6904302: 'MUMU',
6904401: 'CANUDINHO RECHEADO',
6904501: 'SAROLHO',
6904502: 'BEIJU',
6904601: 'SCHIMIER  / CHIMIA DE FRUTA (EXCETO DE CANA)',
6904701: 'BEIJO DE MOCA',
6904801: 'PICOLE ENSACADO',
6904802: 'DIN DIN',
6904804: 'CHUPE CHUPE',
6904807: 'GELINHO, SACOLE',
6905001: 'CHURRO',
6905101: 'PAMONHA',
6905603: 'IOIO CREME (CHOCOLATE EM CREME)',
6905606: 'NUTELLA',
6905702: 'GUARANA EM PO',
6905801: 'OVO DE PASCOA',
6905804: 'KINDER OVO',
6905901: 'TORRONE',
6906001: 'ARROZ-DOCE',
6906404: 'POLPA DE COCO',
6906501: 'DIET SHAKE',
6906502: 'CONCENTRADO ALIMENTAR DIET SHAKE',
6906503: 'HERBALIFE',
6906602: 'ACUCAR',
6907001: 'ACUCAR LIGHT',
6907201: 'BARRA DE CEREAIS',
6907202: 'BARRA DE CEREAIS SALGADA',
6907203: 'BARRA DE CEREAIS DOCE',
6907401: 'RABANADA',
6907501: 'MILK SHAKE',
6907901: 'GELEIA DIET',
6908001: 'DOCE DE FRUTAS DIET',
6908401: 'PASTEl DE SANTA CLARA',
6908501: 'SUSPIRO',
6909301: 'DOCE DE FRUTAS CRISTALIZADO DE QUALQUER SABOR DIET',
6909601: 'SORVETE DE QUALQUER SABOR INDUSTRIALIZADO LIGHT',
6909701: 'SORVETE DE QUALQUER SABOR INDUSTRIALIZADO DIET',
6909803: 'BALA LIGHT',
6909901: 'CHICLETE DIET',
6909903: 'BALA DIET',
6910002: 'BARRA DE CHOCOLATE LIGHT',
6910102: 'BARRA DE CHOCOLATE DIET',
6910221: 'ACHOCOLATADO EM PO LIGHT',
6910321: 'ACHOCOLATADO EM PO DIET',
6910322: 'TODDYNHO DIET',
6910401: 'BOMBOM DE QUALQUER MARCA LIGHT',
6910501: 'BOMBOM DE QUALQUER MARCA DIET',
6910502: 'BOMBOM CARAMELIZADO DE QUALQUER MARCA DIET',
6910601: 'GELEIA DE FRUTAS DE QUALQUER MARCA OU SABOR LIGHT',
6910604: 'GELEIA LIGHT',
6910605: 'GELEIA DE FRUTAS LIGHT',
6910701: 'DOCE DE FRUTAS EM BARRA OU PASTA LIGHT',
6910702: 'DOCE DE FRUTAS EM PASTA LIGHT',
6910801: 'PUDIM DE QUALQUER SABOR LIGHT',
6910808: 'PUDIM DANETTE LIGHT',
6910901: 'PUDIM DE QUALQUER SABOR DIET',
6911201: 'DOCE DE LEITE LIGHT',
6911301: 'DOCE DE LEITE DIET',
6912501: 'BARRA DE CEREAIS DIET',
6912502: 'BARRA DE CEREAIS DOCE DIET',
6912801: 'MILK SHAKE DIET',
6913001: 'COCADA DIET',
6913101: 'DOCE DE AMENDOIM DIET',
6913103: 'PACOCA DIET',
6913108: 'AMENDOIM AMANTEIGADO DIET',
6913801: 'DOCE A BASE DE LEITE DIET',
6913901: 'GELATINA DE QUALQUER SABOR LIGHT / DIET',
6914001: 'ADOCANTE LIGHT',
6914002: 'ADOCANTE EM PO LIGHT',
6914003: 'ADOCANTE LIQUIDO LIGHT',
6914901: 'SORVETE A BASE DE IOGURTE',
6915001: 'SORVETE DE CASQUINHA / CONE',
6915101: 'SORVETE SUNDAE',
6915202: 'SUSPIRO RECHEADO',
6915302: 'PUDIM DE CHOCOLATE',
6915304: 'PUDIM DE LEITE',
6915306: 'PUDIM DE PAO',
6915308: 'PUDIM DE SORVETE',
6915310: 'PUDIM FLAN',
6915501: 'AMENDOAS CARAMELIZADAS',
6915502: 'CASTANHA DE CAJU CARAMELIZADA',
6915503: 'CASTANHA-DO-PARA CARAMELIZADA',
6915504: 'MISTURA DE CASTANHAS CARAMELIZADAS',
6915601: 'FRUTA CARAMELADA',
6915602: 'BANANA CARAMELADA',
6915603: 'BANANA FLAMBADA',
6915701: 'BANANA PASSA COBERTA DE CHOCOLATE',
6915702: 'BANANINHA COM CHOCOLATE',
6915801: 'CAJUZINHO',
6915901: 'CALDA DE CARAMELO',
6915902: 'CALDA DE CHOCOLATE',
6915904: 'CALDA SABOR FRUTA (MORANGO, ETC)',
6915905: 'EXTRATO DE MALTE',
6915907: 'XAROPE DE MAPLE',
6916001: 'CAMAFEU',
6916101: 'CREME BRULE',
6916201: 'DOCE ARABE',
6916202: 'ATAIF',
6916301: 'DOCE DE FEIJAO',
6916401: 'DOCES (CONFEITARIA) NAO ESPECIFICADO',
6916501: 'MACA DO AMOR',
6916601: 'MARRON GLACE',
6916701: 'MARZIPA',
6916801: 'OLHO DE SOGRA',
6916901: 'PASTEL COM RECHEIO DOCE',
6917001: 'PASTEL DE NATA',
6917101: 'PERA AO VINHO',
6917201: 'PETIT GATEAU',
6917301: 'TOUCINHO DO CEU',
6917401: 'WAFFLE',
6980001: 'DOCE DE ABOBORA',
6980101: 'DELICIA DE ABACAXI',
6980201: 'SUFLE DE CHOCOLATE',
7001001: 'CANELA',
7001501: 'MOSTARDA MOLHO',
7002304: 'HORTELA',
7002601: 'COENTRO',
7003601: 'MOLHO DE SOJA',
7003604: 'SHOYO',
7003801: 'LEITE DE COCO',
7003901: 'MOLHO TARTARO',
7004301: 'MAIONESE (MOLHO)',
7004801: 'MOLHO DE TOMATE',
7004802: 'KETCHUP',
7004803: 'CATCHUP',
7006101: 'PIMENTA EM PO',
7007101: 'TUCUPI EM CALDO',
7007502: 'CREME DE QUEIJO',
7007701: 'CALDO DE PEIXE',
7007901: 'CALDO DE TOMATE',
7009102: 'GERGELIM',
7010301: 'TOMATE SECO',
7010401: 'MAIONESE (MOLHO) LIGHT',
7010501: 'MOLHO DE SOJA LIGHT',
7010601: 'LEITE DE COCO LIGHT',
7079202: 'VINAGRETE',
7080001: 'VINAGRE',
7080101: 'SAL',
7080301: 'MOLHO PARA SALADA',
7080401: 'CONSERVA DE BERINJELA',
7100101: 'FILE MIGNON',
7100201: 'CONTRAFILE',
7100205: 'BISTECA BOVINA',
7100301: 'ALCATRA',
7100303: 'MAMINHA',
7100304: 'PICANHA',
7100502: 'CABECA DE LOMBO (CARNE BOVINA)',
7100604: 'POSTA BRANCA',
7100606: 'TATU (LAGARTO REDONDO)',
7100607: 'PAULISTA',
7100608: 'LOMBO PAULISTA (CARNE BOVINA)',
7100702: 'POSTA VERMELHA',
7101001: 'MUSCULO BOVINO',
7101006: 'CHAMBARIL',
7101009: 'CARNE MARICA BOVINA',
7101011: 'VAZIO (CARNE BOVINA)',
7101014: 'OSSOBUCO',
7101202: 'FRALDINHA (CAPA DE FILE)',
7101301: 'COSTELA BOVINA',
7101801: 'VISCERA BOVINA',
7101806: 'PANELADA',
7101901: 'CORACAO BOVINO',
7102001: 'RIM BOVINO',
7102102: 'BOFE BOVINO',
7102201: 'MIOLO BOVINO',
7102401: 'TRIPA BOVINA',
7102402: 'DOBRADINHA FRESCA',
7102403: 'FATO BOVINO',
7102404: 'FATO CAPRINO',
7102501: 'FIGADO BOVINO',
7102502: 'FIGADO BOVINO (BIFE)',
7102601: 'CUPIM',
7102701: 'LINGUA BOVINA',
7102801: 'RABADA BOVINA',
7103101: 'MOCOTO BOVINO',
7103104: 'BRACO BOVINO',
7103105: 'MAO BOVINA',
7103301: 'CARRE',
7103303: 'COSTELETA',
7103305: 'BISTECA SUINA / BISTECA DE PORCO',
7103401: 'PERNIL (CABRITO / OVELHA / CORDEIRO)',
7103403: 'QUARTO SUINO',
7103501: 'COSTELA SUINA / COSTELA DE PORCO',
7103701: 'LOMBO SUINO / LOMBO DE PORCO',
7103801: 'TOUCINHO',
7103903: 'MIUDO SUINO / MIUDO DE PORCO',
7103906: 'ARRASTO SUINO',
7103907: 'SARAPATEL SUINO FRESCO',
7104101: 'CARNE SUINA / CARNE DE PORCO',
7104102: 'CARNE DE PORCO',
7104301: 'CARNE MOIDA',
7104302: 'GUISADO / GUIZADO',
7104303: 'GOULASH',
7104501: 'TRIPA SUINA / PORCO',
7104601: 'FIGADO SUINO / FIGADO DE PORCO',
7104602: 'FIGADO SUINO / FIGADO DE PORCO  (BIFE)',
7104701: 'LINGUA SUINA / LINGUA DE PORCO',
7105001: 'ORELHA SUINA FRESCA',
7105103: 'SARRABULHO',
7105203: 'MOCOTO SUINO / MOCOTO DE PORCO',
7105401: 'CARNE DE CABRITO',
7105402: 'CARNE DE BODE',
7105403: 'CARNE CAPRINA',
7105405: 'CARNE DE CAPRINO',
7105601: 'CARNE DE CARNEIRO',
7105602: 'CARNE DE OVELHA',
7105801: 'MOCOTO DE CAPRINO',
7106301: 'PERNIL (DE PORCO / SUINO)',
7107102: 'BRACHOLA',
7107204: 'BUCHADA DE BODE',
7107206: 'BUCHO / DOBRADINHA ENSOPADO(A)',
7107501: 'SUA SUINA',
7107601: 'CARNE DE OUTROS ANIMAIS',
7107603: 'CARNE DE PACA',
7107611: 'CARNE DE JACARE',
7107615: 'CARNE DE CAPIVARA',
7107617: 'CARNE DE COTIA',
7107622: 'CARNE DE JABUTI',
7107804: 'CHULETA',
7108107: 'MIUDO DE BODE',
7108902: 'BIFE',
7109101: 'CARNE BOVINA',
7110902: 'OSSADA',
7112501: 'COELHO',
7112502: 'CORDEIRO',
7112601: 'BIFE A MILANESA',
7112701: 'BIFE A ROLE',
7112702: 'ROLE DE CARNE',
7112801: 'BIFE DE PANELA',
7112802: 'CARNE DE PANELA',
7112901: 'JOELHO DE PORCO',
7113001: 'KAFTA',
7113101: 'LEITAO',
7113201: 'LOMBINHO',
7113301: 'LOMBO',
7113401: 'MEDALHOES BOVINOS',
7113402: 'TORNEDOR BOVINO',
7113501: 'VITELA',
7180001: 'ROSBIFE',
7200101: 'PEIXE DO MAR',
7200401: 'PEIXE SALGADO',
7260101: 'CAMARAO',
7261101: 'SIRI',
7261112: 'PATINHA DE CARANGUEJO',
7261120: 'BAU (SIRI)',
7261121: 'GOIA',
7262101: 'CARANGUEJO',
7262105: 'GUAIAMU / GUAIAMUM',
7263101: 'MARISCO',
7263102: 'MEXILHAO',
7264101: 'OSTRA',
7265101: 'LULA',
7266101: 'SURURU',
7266106: 'AMEIJOA, LAMBRETA, VANGOLE, VIEIRAS, COQUILLE, COQUILHA, SARNAMBI',
7266107: 'BERBIGAO',
7267101: 'LAGOSTA',
7267104: 'LAGOSTIM',
7270401: 'BACALHAU',
7273101: 'OVAS DE PEIXE (QUALQUER ESPECIE)',
7273102: 'CAVIAR',
7274101: 'POLVO',
7280001: 'NUGGETS DE PEIXE',
7280101: 'CEVICHE DE FRUTOS DO MAR',
7280102: 'CEVICHE DE PEIXE',
7280201: 'DOURADO NA FOLHA DE BANANEIRA',
7280301: 'SASHIMI',
7280401: 'TARTARE DE SALMAO',
7280501: 'FILE DE PEIXE',
7280601: 'PITU',
7281201: 'ATUM FRESCO',
7281401: 'FRUTOS DO MAR',
7281501: 'STEAK DE PEIXE',
7400101: 'PEIXE DE AGUA DOCE',
7400401: 'PEIXE DE AGUA DOCE SALGADO',
7444101: 'TRACAJA',
7480001: 'PACU',
7480101: 'TAMBAQUI',
7480201: 'TUCUNARE',
7600101: 'PEIXE NAO ESPECIFICADO (EM POSTA, EM FILE, ETC)',
7600401: 'PEIXE NAO ESPECIFICADO SALGADO (EM POSTA, EM FILE, ETC)',
7700101: 'AZEITONA',
7700201: 'ERVILHA EM CONSERVA',
7700202: 'PETIT POIS',
7700401: 'MILHO VERDE EM CONSERVA',
7700501: 'PALMITO EM CONSERVA',
7700601: 'COGUMELO EM CONSERVA',
7700602: 'CHAMPIGNON EM CONSERVA',
7700701: 'ASPARGO EM CONSERVA',
7700901: 'REPOLHO EM CONSERVA',
7700902: 'CHUCRUTE',
7701101: 'LEGUME NAO ESPECIFICADO EM CONSERVA',
7701406: 'YAKISSOBA',
7701501: 'MILHO VERDE COM ERVILHA EM CONSERVA',
7701901: 'FEIJOADA',
7702001: 'FEIJAO BRANCO COM DOBRADINHA EM CONSERVA',
7702101: 'COZIDO',
7702102: 'PUCHERO',
7702302: 'PASTA DE CARNE EM CONSERVA',
7702402: 'PASTA DE PRESUNTO EM CONSERVA',
7702502: 'PASTA DE GALINHA EM CONSERVA',
7702601: 'CARNE BOVINA EM CONSERVA',
7702602: 'ALMONDEGA',
7702603: 'KITUTE BOVINO',
7702704: 'KITUTE SUINO / KITUTE DE PORCO',
7702705: 'PRESUNTADA',
7702707: 'FIAMBRE',
7702801: 'SALSICHA EM CONSERVA',
7703002: 'SARDINHA EM CONSERVA',
7703402: 'ATUM EM CONSERVA',
7703701: 'PEPINO EM CONSERVA',
7703902: 'PASTA DE PEIXE EM CONSERVA',
7704001: 'PICLES',
7705201: 'NABO EM CONSERVA',
7705401: 'STROGONOFF / ESTROGONOFE',
7705901: 'KANI KAMA',
7706001: 'SALMAO EM CONSERVA',
7706302: 'ATUM EM CONSERVA LIGHT',
7800301: 'PARTE DE GALINHA OU FRANGO NAO ESPECIFICADA',
7800302: 'FRANGO EM PEDACOS',
7800303: 'GALINHA EM PEDACOS',
7800304: 'CARNE DE GALINHA',
7800307: 'FRANGO DESFIADO',
7800401: 'PEITO DE GALINHA OU FRANGO',
7800402: 'FILE DE FRANGO',
7800503: 'SOBRECOXA / COXA DE FRANGO / GALINHA',
7800701: 'ASA DE GALINHA OU FRANGO',
7800702: 'DRUMETE DE GALINHA OU FRANGO',
7800801: 'PESCOCO DE GALINHA OU FRANGO',
7800901: 'PE DE GALINHA OU FRANGO',
7801001: 'MIUDO DE GALINHA OU FRANGO',
7801101: 'MOELA DE GALINHA OU FRANGO',
7801202: 'CORACAO DE FRANGO',
7801301: 'FIGADO DE GALINHA OU FRANGO',
7801407: 'CANJA',
7801702: 'PERU EM PEDACO NAO ESPECIFICADO',
7801801: 'PEITO DE PERU',
7801901: 'COXA DE PERU',
7802101: 'ASA DE PERU',
7802701: 'CHESTER',
7802702: 'TENDER',
7802801: 'NAMBU',
7802901: 'NUGGETS DE FRANGO',
7802902: 'STEAK DE FRANGO',
7802905: 'NUGGET RECHEADO',
7802906: 'NUGGETS, OUTROS',
7803001: 'CODORNA',
7803201: 'PE E ASA DE GALINHA OU FRANGO',
7803301: 'OVO DE GALINHA',
7803501: 'OVO DE CODORNA',
7803702: 'GALINHA DANGOLA',
7803703: 'CAPOTE',
7803707: 'MUTUM',
7803907: 'PATO EM PEDACOS',
7803908: 'PEITO DE PATO',
7803913: 'CARNE DE PATO',
7805401: 'PEITO DE PERU LIGHT',
7806002: 'MARRECO, CARNE NAO ESPECIFICADO',
7806201: 'CARNE MOIDA DE FRANGO',
7807101: 'OVO CLARA',
7807201: 'OVO GEMA',
7807301: 'OVOS MEXIDOS',
7807401: 'OVOS MOLES',
7807501: 'FRANGO A PASSARINHO',
7807602: 'ROLE DE FRANGO OU GALINHA',
7807702: 'GANSO, CARNE NAO ESPECIFICADO',
7900101: 'LEITE DE VACA INTEGRAL',
7900201: 'LEITE DE VACA FRESCO',
7900301: 'LEITE DE CABRA',
7900601: 'LEITE EM PO INTEGRAL',
7900710: 'LEITE EM PO DESNATADO',
7900801: 'LEITE EM PO',
7900901: 'LEITE CONDENSADO',
7900903: 'LEITE BEIJINHO',
7901001: 'CREME DE LEITE',
7901101: 'CHANTILLY',
7901201: 'IOGURTE DE QUALQUER SABOR',
7901203: 'IOGURTE DESNATADO',
7901204: 'IOGURTE NATURAL',
7901301: 'YAKULT DE QUALQUER SABOR',
7901303: 'BEBIDA LACTEA',
7901304: 'LEITE FERMENTADO',
7901401: 'COALHADA',
7901501: 'MANTEIGA COM OU SEM SAL',
7901505: 'MANTEIGA DE GARRAFA',
7901602: 'MARGARINA COM OU SEM SAL',
7901701: 'QUEIJO PRATO',
7901703: 'QUEIJO COLONIAL',
7901705: 'QUEIJO DE COLONIA',
7901801: 'QUEIJO MUZARELLA',
7901803: 'MUSSARELA / MUCARELA',
7901807: 'MUSSARELA / MUCARELA DE BUFALA',
7901809: 'QUEIJO DE BUFALA',
7901901: 'QUEIJO DE REINO',
7902001: 'QUEIJO DE MINAS',
7902003: 'QUEIJO DE MANTEIGA',
7902004: 'QUECHIMIA',
7902005: 'QUEIJO DE COALHO',
7902008: 'QUEIJO CANASTRA',
7902201: 'QUEIJO RICOTA',
7902301: 'LEITE DE SOJA COM SABOR',
7902303: 'ADES ORIGINAL',
7902403: 'QUEIJO RALADO',
7902501: 'QUEIJO PROVOLONE',
7902801: 'QUEIJO POLENGUINHO',
7902901: 'REQUEIJAO',
7902902: 'QUEIJO CREMOSO',
7903001: 'QUEIJO NAO ESPECIFICADO',
7903101: 'LEITE COM SABOR',
7903102: 'LEITE ACHOCOLATADO',
7903109: 'LEITE AROMATIZADO',
7903110: 'BEBIDA ACHOCOLATADA',
7903201: 'NATA DOCE OU SALGADA',
7903301: 'QUEIJO GORGONZOLA',
7903402: 'TOFU',
7903501: 'LEITE DE SOJA EM PO',
7903601: 'LEITE DE VACA DESNATADO',
7903702: 'LEITE DE VACA SEMIDESNATADO',
7903801: 'LEITE NAO ESPECIFICADO PASTEURIZADO',
7903901: 'IOGURTE DE QUALQUER SABOR LIGHT',
7904001: 'IOGURTE DE QUALQUER SABOR DIET',
7904201: 'MARGARINA LIGHT',
7905103: 'MUSSARELA / MUCARELA LIGHT',
7905104: 'QUEIJO MUSSARELA / MUCARELA LIGHT',
7905201: 'LEITE DE SOJA COM SABOR LIGHT',
7905203: 'ADES LIGHT',
7905601: 'CREME DE LEITE LIGHT',
7905901: 'QUEIJO PRATO LIGHT',
7906001: 'QUEIJO DE MINAS LIGHT',
7906005: 'QUEIJO DE COALHO LIGHT',
7906201: 'QUEIJO RICOTA LIGHT',
7906303: 'QUEIJO RALADO LIGHT',
7906401: 'QUEIJO POLENGUINHO LIGHT',
7906501: 'REQUEIJAO LIGHT',
7906601: 'QUEIJO NAO ESPECIFICADO LIGHT',
7906702: 'LEITE ACHOCOLATADO LIGHT',
7906710: 'BEBIDA ACHOCOLATADA LIGHT',
7906801: 'LEITE COM SABOR DIET',
7906802: 'LEITE ACHOCOLATADO DIET',
7906810: 'BEBIDA ACHOCOLATADA DIET',
7906901: 'LEITE DE SOJA EM PO LIGHT',
7907001: 'LEITE EM PO COM SABOR',
7907101: 'MANTEIGA COM OU SEM SAL LIGHT',
7980001: 'LEITE SEM LACTOSE',
7980101: 'KEFIR',
8000101: 'PAO FRANCES',
8000102: 'PAO DAGUA',
8000103: 'PAO DE HAMBURGUER',
8000105: 'PAO DE SAL',
8000106: 'PAO DE TRIGO',
8000107: 'PAO CACETINHO',
8000109: 'PAO CARECA',
8000145: 'PAO CIABATA',
8000157: 'PAO BRANCO NAO ESPECIFICADO',
8000158: 'PAOZINHO',
8000201: 'PAO DOCE',
8000203: 'CHINEQUE',
8000208: 'PAO DOCE COM RECHEIO',
8000213: 'PAO DE LEITE',
8000218: 'CHINEQUE COM FAROFA',
8000223: 'PAO DE COCO',
8000229: 'PAO DE MEL',
8000231: 'PAO ALEMAO (PUMPERNICKEL)',
8000234: 'PANETONE',
8000237: 'BISNAGUINHA',
8000240: 'CROISSANT',
8000245: 'PAO AUSTRALIANO',
8000249: 'PAO DOCE SEM RECHEIO',
8000250: 'VANDERLEIA',
8000501: 'PAO DE FORMA INDUSTRIALIZADO DE QUALQUER MARCA',
8000801: 'PAO DE QUEIJO',
8001101: 'PAO DE MILHO',
8001301: 'PAO DE CENTEIO',
8001302: 'PAO PRETO NAO ESPECIFICADO',
8001401: 'PAO INTEGRAL',
8001407: 'PAO ARABE INTEGRAL',
8001408: 'PAO CACETINHO INTEGRAL',
8001409: 'PAO CARECA INTEGRAL',
8001410: 'PAO CENTEIO INTEGRAL',
8001411: 'PAO DE SAL INTEGRAL',
8001412: 'PAO DE TRIGO INTEGRAL',
8001413: 'PAO FRANCES INTEGRAL',
8001414: 'PAOZINHO INTEGRAL',
8001501: 'PAO NAO ESPECIFICADO',
8001901: 'TORRADA DE QUALQUER PAO',
8002001: 'ROSCA DOCE',
8002002: 'ROSQUINHA DOCE',
8002101: 'ROSCA SALGADA',
8002106: 'ROSQUINHA SALGADA',
8002201: 'BISCOITO SALGADO',
8002205: 'PRESUNTINHO BISCOITO',
8002212: 'BISCOITO DE POLVILHO',
8002217: 'GRESSINI / GRISSINI (PALITO DE PAO)',
8002225: 'BOLACHA SALGADA',
8002227: 'CHIPS (SALGADINHOS)',
8002230: 'BACONZITOS',
8002236: 'BISCOITO SALGADO INTEGRAL',
8002246: 'SALGADINHO DE MILHO (TIPO DORITOS, FANDANGOS, CHEETOS)',
8002252: 'TORRADA CENTEIO',
8002253: 'TORRADA DOCE',
8002254: 'TORRADA INTEGRAL',
8002255: 'SALGADINHO BATATA CHIPS (TIPO RUFFLES)',
8002256: 'SALGADINHO TIPO TORCIDA',
8002301: 'BISCOITO DOCE',
8002302: 'CAVACO CHINES',
8002305: 'SEQUILHO',
8002306: 'TARECO',
8002309: 'SOLDA/ SODA/ BOLACHA DE RAPADURA',
8002315: 'BREVIDADE',
8002334: 'BOLACHA DOCE',
8002335: 'MARIA MALUCA (BOLACHA DOCE)',
8002405: 'QUEBRA QUEBRA',
8002502: 'ROCAMBOLE',
8002503: 'CUCA DE QUALQUER TIPO',
8002508: 'ROCAMBOLE DOCE',
8002509: 'BOLO DE ROLO',
8002601: 'BOLO DE MILHO',
8002605: 'ANGUSOR DE MILHO',
8002609: 'GRUSTOLI (BOLINHO DOCE)',
8002612: 'BOLO DE FUBA',
8002613: 'BOLO DE FUBA CREMOSO',
8002701: 'BOLO DE AIPIM',
8002702: 'BOLO DE TAPIOCA',
8002703: 'BOLO DE MACAXEIRA',
8002704: 'BOLO DE GOMA',
8002705: 'BOLO DE MANDIOCA',
8002709: 'BOLO DE MANIVA',
8002801: 'BOLO DE BATATA DOCE',
8002901: 'BOLO DE ARROZ',
8003101: 'BOLO DE CARA',
8003501: 'TORTAS DOCES DE QUALQUER SABOR',
8003503: 'STRUDEL DE MACA',
8003601: 'TORTAS SALGADAS DE QUALQUER SABOR',
8003701: 'SONHO',
8003702: 'FILHOS (BOLINHO DE FARINHA DE TRIGO E OVOS)',
8003703: 'SONHO RECHEADO COBERTO COM ACUCAR',
8003704: 'SONHO RECHEADO COM COBERTURA DE CHOCOLATE',
8003801: 'BOLO DE CHOCOLATE',
8003802: 'MUFFIN',
8003902: 'BRIOCHE',
8004001: 'BOLO DE LARANJA',
8004101: 'BOLO DE COCO',
8004201: 'BOLO DE CENOURA',
8004403: 'PAO DE ALHO',
8004601: 'BOLO DE TRIGO',
8004602: 'PAO DE LO',
8004603: 'BOLO SIMPLES',
8004701: 'BROA',
8004801: 'BISCOITO RECHEADO',
8004807: 'WAFFER / WAFER (BISCOITO)',
8004809: 'ALFAJORES (BISCOITO)',
8004810: 'BOLACHA RECHEADA',
8004813: 'ROSCA RECHEADA',
8004814: 'ROSQUINHA RECHEADA DE QUALQUER SABOR',
8005201: 'BISCOITO NAO ESPECIFICADO',
8006101: 'CREPE',
8006102: 'CREPE / PANQUECA DOCE',
8006103: 'CREPE / PANQUECA DE CHOCOLATE',
8006104: 'CREPE / PANQUECA DE DOCE DE LEITE',
8006105: 'CREPE / PANQUECA DE FRUTA COM ACUCAR E CANELA',
8006106: 'CREPE / PANQUECA DE FRUTA COM CHANTILLY',
8006107: 'CREPE / PANQUECA DE GELEIA',
8006108: 'CREPE / PANQUECA DE NUTELLA',
8006401: 'PAO ARABE',
8006501: 'PAO DIET (DE FORMA INDUSTRIALIZADO)',
8006601: 'PAO LIGHT (DE FORMA INDUSTRIALIZADO)',
8006701: 'PAO DE QUEIJO LIGHT',
8006801: 'PAO INTEGRAL LIGHT',
8007001: 'TORTAS DOCES DE QUALQUER SABOR LIGHT',
8007101: 'TORTAS DOCES DE QUALQUER SABOR DIET',
8007302: 'FILHOS (BOLINHO DE FARINHA DE TRIGO E OVOS) LIGHT',
8007402: 'FILHOS (BOLINHO DE FARINHA DE TRIGO E OVOS) DIET',
8007501: 'BOLO DE CHOCOLATE LIGHT',
8007601: 'BOLO DE CHOCOLATE DIET',
8007701: 'BOLO DE LARANJA LIGHT',
8008001: 'BOLO DE COCO DIET',
8008201: 'BOLO DE CENOURA DIET',
8008301: 'BISCOITO RECHEADO LIGHT',
8008305: 'BISCOITO WAFFER / WAFER LIGHT',
8008307: 'WAFFER / WAFER (BISCOITO) LIGHT',
8008309: 'ALFAJORES (BISCOITO) LIGHT',
8008310: 'BOLACHA RECHEADA LIGHT',
8008401: 'BISCOITO RECHEADO DIET',
8008408: 'ROSQUINHA RECHEADA DE QUALQUER SABOR DIET',
8008410: 'BOLACHA RECHEADA DIET',
8010001: 'PAO DOCE DIET',
8010029: 'PAO DE MEL DIET',
8010034: 'PANETONE DIET',
8010101: 'BISCOITO SALGADO LIGHT',
8010125: 'BOLACHA SALGADA LIGHT',
8010127: 'CHIPS (SALGADINHOS) LIGHT',
8010401: 'BISCOITO DOCE LIGHT',
8010434: 'BOLACHA DOCE LIGHT',
8010501: 'BISCOITO DOCE DIET',
8010534: 'BOLACHA DOCE DIET',
8010601: 'BOLO DE BANANA',
8010602: 'BOLO DE ABACAXI',
8010604: 'BOLO DE FRUTA',
8010605: 'BOLO DE LIMAO',
8011601: 'PAO PARA WRAP',
8011602: 'PAO SEM GLUTEN',
8011701: 'PAO DE BATATA',
8011801: 'PAO DE BATATA RECHEADO',
8011901: 'SALGADINHO DE ARROZ (TIPO CAMIL)',
8012601: 'BOLO CUCA',
8012602: 'CUCA ALEMA',
8012701: 'BOLO DE ABOBORA',
8012702: 'BOLO DE CENOURA COM RECHEIO E COBERTURA DE CHOCOLATE',
8012901: 'BOLO DE CENOURA SEM RECHEIO COM COBERTURA',
8013001: 'BOLO DE CHOCOLATE COM RECHEIO E COBERTURA',
8013101: 'BOLO DE FECULA DE BATATA',
8013201: 'BOLO DIET SIMPLES',
8013301: 'BOLO DOCE COM RECHEIO E COBERTURA',
8013302: 'CUPCAKE',
8013303: 'PROFITEROLES (COM RECHEIO E COBERTURA DE CHOCOLATE)',
8013401: 'BOLO INGLES',
8013501: 'CREPE / PANQUECA COM RICOTA E ESPINAFRE',
8013601: 'BROWNIE',
8013701: 'CHEESECAKE',
8013801: 'CROISSANT COM RECHEIO DOCE',
8013901: 'CROISSANT COM RECHEIO SALGADO',
8014001: 'MADALENA',
8014101: 'PANETONE SALGADO',
8014301: 'PRETZELS',
8080001: 'PAO CASEIRO',
8080101: 'TAPIOCA',
8080102: 'TAPIOCA RECHEIO NAO-ESPECIFICADO',
8080103: 'TAPIOCA DOCE RECHEADA',
8080104: 'TAPIOCA RECHEADA COM CARNE E QUEIJO',
8080105: 'TAPIOCA RECHEADA COM QUEIJO',
8080106: 'TAPIOCA SALGADA RECHEADA',
8100101: 'CARNE SECA',
8100102: 'CARNE DE CHARQUE',
8100103: 'JABA',
8100201: 'CARNE DE SOL',
8100202: 'CARNE DO SERTAO',
8100502: 'HAMBURGUER DE CARNE BOVINA',
8100802: 'COPA DE PORCO DEFUMADA',
8101005: 'BACON',
8101101: 'HAMBURGUER DE FRANGO',
8102101: 'SALSICHA',
8102103: 'SALSICHAO',
8102204: 'LINGUICA  (SUINA, BOVINA, MISTA, ETC)',
8102205: 'LINGUICA CALABRESA',
8102207: 'LINGUICA DE FRANGO',
8102401: 'CHOURICO',
8102402: 'MORCELA',
8102403: 'MORCILHA',
8102501: 'PAIO',
8102601: 'MORTADELA',
8102701: 'SALAME',
8102702: 'SALAMINHO',
8102801: 'BLANQUET DE PERU',
8102901: 'PRESUNTO',
8102905: 'PRESUNTO PARMA',
8103001: 'HAMBURGUER DE PERU',
8103003: 'HAMBURGUER DE PEIXE',
8103101: 'HAMBURGUER NAO ESPECIFICADO',
8103601: 'APRESUNTADO',
8103901: 'PURURUCA DE PORCO',
8103902: 'PELE DE PORCO PREPARADA',
8103903: 'LEITAO A PURURUCA',
8104001: 'PATE (FIGADO, CALABRES, FRANGO, PRESUNTO, ETC)',
8104101: 'CARNE DE AVES DEFUMADA',
8104601: 'CARNE SALGADA NAO ESPECIFICADA',
8104904: 'MINI CHICKEN EMPANADO',
8105001: 'MORTADELA LIGHT',
8105201: 'SALSICHA LIGHT',
8105401: 'SALAME LIGHT',
8105501: 'BLANQUET DE PERU LIGHT',
8105701: 'HAMBURGUER NAO ESPECIFICADO LIGHT',
8106901: 'SARDELA',
8200101: 'REFRIGERANTE DE COLA TRADICIONAL',
8200102: 'COCA COLA TRADICIONAL',
8200202: 'FANTA LARANJA TRADICIONAL',
8200208: 'SUKITA TRADICIONAL',
8200211: 'REFRIGERANTE DE LARANJA TRADICIONAL',
8200301: 'REFRIGERANTE DE GUARANA TRADICIONAL',
8200302: 'GUARANA TRADICIONAL',
8200308: 'REFRESCO DE GUARANA NATURAL',
8200407: 'SPRITE REFRIGERANTE TRADICIONAL',
8200411: 'REFRIGERANTE DE LIMAO TRADICIONAL',
8200505: 'FANTA UVA TRADICIONAL',
8200507: 'REFRIGERANTE DE UVA TRADICIONAL',
8200701: 'REFRIGERANTE DE COLA LIGHT',
8200702: 'COCA COLA LIGHT',
8200801: 'REFRIGERANTE DE COLA DIET',
8200902: 'MINUANO TRADICIONAL',
8201004: 'AGUA MINERAL',
8201005: 'AGUA MINERAL SEM GAS',
8201007: 'AGUA MINERAL COM GAS',
8201015: 'AGUA MINERAL GASEIFICADA COM SUMO DE FRUTA',
8201017: 'BEBIDA REFRIGERANTE, TIPO H2O',
8201104: 'MATE TRADICIONAL',
8201202: 'BIDU TRADICIONAL',
8201502: 'FANTA LARANJA LIGHT',
8201511: 'REFRIGERANTE DE LARANJA DIET',
8201601: 'REFRIGERANTE DE GUARANA LIGHT',
8201602: 'GUARANA LIGHT',
8201802: 'TUBAINA TRADICIONAL',
8201902: 'TUBAINA LIGHT',
8202001: 'CALDO DE CANA',
8202002: 'GARAPA',
8202101: 'AGUA DE COCO',
8202402: 'Q-SUCO',
8202403: 'Q-REFRESKO',
8202701: 'CHA PRETO',
8202801: 'CHA MATE',
8202803: 'ERVA MATE',
8202804: 'CHIMARRAO',
8202805: 'TERERE',
8203401: 'LEVEDO DE CERVEJA',
8203501: 'REFRIGERANTE NAO ESPECIFICADO',
8203603: 'CEVADA EM PO',
8203605: 'CEVADA (GRAO)',
8204503: 'CHOCOMILK',
8204902: 'AGUA TONICA TRADICIONAL',
8205201: 'CHA DIET (PRETO, CAMOMILA, ERVA CIDREIRA, CAPIM LIMAO, ETC)',
8205402: 'PARAGUAI REFRIGERANTE TRADICIONAL',
8205801: 'ENERGETICO',
8205803: 'GATORADE',
8205805: 'BEBIDA ISOTONICA',
8205901: 'BEBIDA ENERGETICA',
8206301: 'CHA (PRETO, CAMOMILA, ERVA CIDREIRA, CAPIM LIMAO, ETC)',
8207401: 'REFRIGERANTE DE GUARANA DIET',
8207402: 'GUARANA DIET',
8207501: 'REFRIGERANTE DE LIMAO LIGHT',
8207601: 'REFRIGERANTE DE LIMAO DIET',
8207701: 'REFRIGERANTE DE UVA DIET / LIGHT',
8207705: 'FANTA UVA LIGHT',
8208104: 'MATE LIGHT',
8209002: 'AGUA TONICA LIGHT',
8209102: 'PARAGUAI REFRIGERANTE LIGHT',
8211002: 'Q-SUCO LIGHT',
8211003: 'Q-REFRESKO LIGHT',
8211102: 'Q-SUCO DIET',
8212802: 'MATE DIET',
8212902: 'AGUA TONICA DIET',
8212906: 'REFRIGERANTE DE QUININO DIETETICO',
8213301: 'CHA VERDE, CHA BRANCO, CHA VERMELHO',
8213601: 'SUCO DE CLOROFILA',
8215701: 'CHA PRETO DESCAFEINADO',
8215801: 'CHA VERDE, BRANCO OU VERMELHO DIET OU LIGHT',
8215901: 'CHA, ERVAS NAO ESPECIFICADO',
8216001: 'SUCO COUVE',
8216101: 'SUCO DETOX',
8216201: 'SUCO VERDE',
8216301: 'AGUA',
8216401: 'ICE TEA LIGHT OU DIET',
8216501: 'ICE TEA TRADICIONAL',
8216601: 'LIMONADA',
8216701: 'SUBSTITUTO DE CAFE NAO ESPECIFICADO',
8217001: 'SUCO NATURAL DE FRUTA',
8217101: 'SUCO NATURAL DE VEGETAIS',
8217201: 'SUCO NATURAL, MISTURA DE FRUTAS',
8217301: 'SUCO NATURAL, MISTURA DE FRUTAS E VEGETAIS',
8217401: 'TAMPICO',
8273902: 'CAFE COM FARINHA',
8280001: 'AGUA COM LIMAO OU OUTRAS FRUTAS/ HORTALICAS',
8280101: 'SUCO INDUSTRIALIZADO',
8280201: 'SUCO DE CAJA/ MANGABA/ TAPEREBA E OUTROS REGIONAIS',
8280301: 'SUCO DE MELANCIA',
8280401: 'SUCO DE TAMARINDO',
8280501: 'SUCO DE UVA',
8300101: 'CERVEJA',
8300201: 'CHOPP',
8300301: 'AGUARDENTE',
8300302: 'CACHACA',
8300501: 'BATIDA DE QUALQUER SABOR',
8300502: 'LEITE DE ONCA',
8300701: 'RUM',
8300801: 'VODKA',
8300901: 'GIN',
8301001: 'UISQUE',
8301002: 'WHISKY',
8301201: 'CHAMPANHE',
8301202: 'SIDRA CHAMPANHE',
8301203: 'ESPUMANTE',
8301301: 'VERMUTE',
8301501: 'MARTINI',
8301601: 'CONHAQUE',
8301701: 'DRINK DREHER',
8301901: 'LICOR DE QUALQUER SABOR',
8302409: 'CAJUINA',
8302415: 'VINHO',
8302416: 'CATUABA',
8302901: 'COQUETEL DE FRUTAS',
8303101: 'CAIPIRINHA',
8303102: 'CAIPIVODKA',
8303103: 'CAIPSAQUE / CAIPSAKE',
8303301: 'CERVEJA SEM ALCOOL',
8303401: 'TEQUILA',
8303501: 'BEBIDA ALCOOLICA',
8304301: 'CERVEJA (COM OU SEM ALCOOL) LIGHT',
8304502: 'CAXIRI (AGUARDENTE DE MANDIOCA)',
8304601: 'QUENTAO',
8304801: 'CAPETA',
8304901: 'COQUETEL DE FRUTAS COM ALCOOL',
8305001: 'COQUETEL DE FRUTAS SEM ALCOOL',
8305101: 'CUBA LIBRE',
8305201: 'DRINK - MISTURA DE BEBIDAS',
8305301: 'PISCO SOUR',
8305401: 'PONCHE COM FRUTAS',
8305501: 'SAKE / SAQUE',
8305601: 'SANGRIA',
8305701: 'SIDRA COM FRUTAS, CIDRA COM FRUTAS',
8305801: 'VINHO QUENTE',
8305901: 'VINHO SEM ALCOOL',
8400101: 'AZEITE DE OLIVA',
8400301: 'OLEO DE SOJA',
8400401: 'OLEO DE MILHO',
8400501: 'OLEO DE AMENDOIM',
8400801: 'OLEO DE GIRASSOL',
8403201: 'OLEO NAO ESPECIFICADO',
8403303: 'OLEO MISTO',
8403501: 'OLEO DE DENDE',
8403601: 'OLEO DE COCO',
8500201: 'SALGADINHO',
8500202: 'PASTEL',
8500203: 'CROQUETE',
8500205: 'COXINHA',
8500206: 'EMPADA',
8500207: 'RISSOLE / RIZOLE',
8500209: 'ACARAJE',
8500210: 'TORRESMO',
8500211: 'QUIBE',
8500212: 'ABARA (BAHIA)',
8500213: 'PACOCA DE CARNE DE SOL',
8500215: 'ANGU FRITO',
8500217: 'ANGU DE MILHO',
8500218: 'POLENTA',
8500222: 'ESFIRRA',
8500223: 'ESFIRRA DE CARNE',
8500224: 'ESFIRRA DE QUEIJO',
8500225: 'ESFIRRA DE RICOTA',
8500226: 'ESFIRRA DE FRANGO',
8500227: 'ENROLADINHO',
8500228: 'BOLINHO DE AIPIM',
8500232: 'BOLINHO DE BACALHAU',
8500302: 'CACHORRO QUENTE',
8500303: 'HAMBURGUER (SANDUICHE)',
8500304: 'CHEESBURGUER',
8500305: 'EGGSBURGUER',
8500307: 'BAURU',
8500308: 'AMERICANO',
8500313: 'MISTO QUENTE OU FRIO',
8500315: 'SANDUICHE DE QUEIJO PRATO',
8500316: 'SANDUICHE DE SALAME',
8500317: 'SANDUICHE DE PRESUNTO',
8500318: 'SANDUICHE DE QUEIJO PRATO COM PRESUNTO',
8500319: 'SANDUICHE DE MORTADELA',
8500320: 'SANDUICHE DE QUEIJO MINAS',
8500321: 'CHEESE EGG',
8500322: 'CHEESE TUDO',
8500323: 'SANDUICHE NATURAL',
8500328: 'CACHORRO QUENTE DE FORNO',
8500329: 'X-BURGUER',
8500330: 'X-CHEDDAR',
8500331: 'SANDUICHE PRESUNTO, QUEIJO E TOMATE',
8500332: 'SANDUICHE BAURU',
8500333: 'SANDUICHE DE QUEIJO',
8500334: 'PAO COM SALAME',
8500335: 'PAO COM PRESUNTO',
8500336: 'PAO COM QUEIJO E PRESUNTO',
8500337: 'PAO COM MORTADELA',
8500338: 'SANDUICHE DE ATUM',
8500339: 'PAO COM ATUM',
8500340: 'SANDUICHE DE CARNE ASSADA',
8500341: 'PAO COM CARNE ASSADA',
8500342: 'SANDUICHE DE FILE',
8500343: 'PAO COM FILE',
8500344: 'SANDUICHE DE ROSBIFE',
8500345: 'PAO COM ROSBIFE',
8500346: 'SANDUICHE DE CARNE DE PORCO',
8500347: 'PAO COM CARNE DE PORCO',
8500348: 'SANDUICHE DE FRANGO',
8500349: 'PAO COM FRANGO',
8500350: 'SANDUICHE DE PEITO DE PERU',
8500351: 'PAO COM PEITO DE PERU',
8500352: 'SANDUICHE DE SALMAO',
8500353: 'PAO COM SALMAO',
8500354: 'SANDUICHE DE SARDINHA',
8500355: 'PAO COM SARDINHA',
8500356: 'SANDUICHE  VEGETARIANO',
8500357: 'WRAP FRANGO OU GALINHA',
8500358: 'WRAP DE CARNE',
8500359: 'X-EGG',
8500360: 'X-BACON',
8500361: 'X-EGGCHEESEBACON',
8500362: 'X-TUDO',
8500363: 'PAO COM QUEIJO',
8500364: 'QUEIJO QUENTE',
8500401: 'SUCO',
8500402: 'SUCO DE ABACAXI',
8500403: 'SUCO DE ACEROLA',
8500404: 'SUCO DE BETERRABA',
8500405: 'SUCO DE CUPUACU',
8500406: 'SUCO DE GOIABA',
8500407: 'SUCO DE LARANJA',
8500408: 'SUCO DE LARANJA COM BANANA',
8500409: 'SUCO DE LARANJA E BETERRABA',
8500410: 'SUCO DE LARANJA E CENOURA',
8500411: 'SUCO DE LARANJA CENOURA E BETERRABA',
8500412: 'SUCO DE MAMAO',
8500413: 'SUCO DE MANGA',
8500414: 'SUCO DE MARACUJA',
8500415: 'SUCO DE MELAO',
8500416: 'SUCO DE MORANGO',
8500417: 'SUCO DE PESSEGO',
8500418: 'SUCO DE PESSEGO EM CALDA',
8500501: 'VITAMINA',
8500503: 'VITAMINA DE BANANA',
8500504: 'VITAMINA DE BANANA COM AVEIA',
8500505: 'VITAMINA DE MAMAO',
8500506: 'VITAMINA DE ABACATE',
8500507: 'VITAMINA DE MORANGO',
8500508: 'VITAMINA MISTA',
8500509: 'VITAMINA DE MACA',
8500510: 'VITAMINA DE FRUTA COM LEITE E CEREAL',
8500511: 'VITAMINA DE MANGA',
8500601: 'REFRESCO',
8500602: 'REFRESCO DE CAJU',
8500603: 'REFRESCO DE GROSELHA',
8500604: 'REFRESCO DE LARANJA',
8500605: 'REFRESCO DE MARACUJA',
8500606: 'REFRESCO DE LIMAO',
8500607: 'REFRESCO CLIGHT',
8500608: 'REFRESCO DE GUARANA NATURAL LIGHT / DIET',
8500609: 'REFRESCO TANG',
8500801: 'SALADA OU VERDURA COZIDA, EXCETO DE FRUTA',
8500802: 'SALADA DE MAIONESE',
8500903: 'PIZZA',
8500904: 'LAZANHA',
8500905: 'NHOQUE',
8500906: 'CANELONI',
8500907: 'CAPELETI',
8500909: 'RAVIOLI',
8500910: 'CALZONE',
8500913: 'PANQUECA',
8500914: 'PIZZA CALABREZA',
8500915: 'PIZZA MUCARELA / MUSSARELA',
8500916: 'PIZZA PRESUNTO',
8500917: 'PIZZA PORTUGUESA',
8500919: 'MACARRONADA',
8500921: 'LASANHA',
8500922: 'CAPELETTI DE CARNE',
8500923: 'CAPELETTI DE FRANGO',
8500924: 'PIZZA DE PEPPERONI',
8500927: 'PIZZA DE QUEIJOS',
8500928: 'PIZZA DE LOMBINHO DEFUMADO',
8500929: 'PIZZA DE MUCARELA E PEITO DE PERU',
8500930: 'PIZZA NAPOLITANA',
8500932: 'PIZZA DE FRANGO COM CATUPIRY',
8500934: 'PIZZA DE PEIXE (ATUM, SALMAO, SARDINHA)',
8500935: 'PIZZA DE MUCARELA DE BUFALA E TOMATE SECO',
8500936: 'PIZZA MARGUERITA (MUCARELA, TOMATE E MANJERICAO)',
8500937: 'PIZZA VEGETARIANA',
8500938: 'PIZZA DOCE DE QUALQUER SABOR',
8500939: 'PIZZA HAWAIANA (QUEIJO, PRESUNTO E ABACAXI)',
8501004: 'GALETO',
8501104: 'COSTELA',
8501202: 'PIPOCA DOCE OU SALGADA',
8501302: 'CAFE',
8501303: 'CAFE COM LEITE',
8501304: 'CAFE TIPO EXPRESSO',
8501305: 'CAFE TIPO CAPUCCINO',
8501306: 'CAFE CAPPUCINO DESCAFEINADO',
8501307: 'CAFE CAPPUCINO LIGHT / DIET',
8501308: 'CAFE CARIOCA',
8501309: 'CAFE COM SUBSTITUTO DO LEITE',
8501310: 'CAFE DESCAFEINADO',
8501311: 'CAFE EXPRESSO DESCAFEINADO',
8501402: 'MILHO COZIDO',
8501502: 'BATATA PALITO',
8501503: 'BATATA PALHA',
8501902: 'MUNGUNZA',
8501903: 'CANJICA',
8501904: 'CURAU',
8501906: 'CURAU DE MILHO',
8502101: 'FAROFA PRONTA LIGHT',
8502201: 'FAROFA',
8502202: 'FAROFA COM CARNE  / LINGUICA/  BACON',
8502204: 'FAROFA COM OVOS',
8502206: 'FAROFA DE COUVE',
8502301: 'MINGAU (FUBA, AVEIA, FARINHA, ETC)',
8502401: 'TACACA',
8502501: 'BOLINHO DE COCO',
8502701: 'RISOTO',
8502801: 'VATAPA',
8502901: 'FAROFA PRONTA',
8503202: 'CALDO DE CARNE',
8503203: 'CALDO DE FEIJAO',
8503204: 'CALDO DE MOCOTO',
8503208: 'MOCOTO BOVINO COM FEIJAO BRANCO',
8503501: 'BAIAO DE DOIS',
8503502: 'RUBACAO',
8503801: 'CHURRASCO',
8503802: 'CHURRASQUINHO',
8504201: 'SUSHI',
8504401: 'SALADA DE FRUTAS',
8504501: 'SOPA (LEGUMES, CARNE, ETC)',
8504503: 'SOPA / CREME DE ABOBORA',
8504504: 'SOPA / CALDO DE CAMARAO',
8504506: 'SOPA DE FEIJAO',
8504507: 'SOPA DE FEIJAO COM MACARRAO',
8504509: 'SOPA DE FRANGO COM LEGUMES',
8504510: 'SOPA DE FUBA',
8504511: 'SOPA DE FUBA COM COUVE / LEGUMES',
8504513: 'SOPA DE LEGUMES',
8504515: 'SOPA DE ENTULHO',
8504517: 'SOPA / CALDO DE MANDIOCA / MANDIOQUINHA / BATATA BAROA / INHAME',
8504519: 'SOPA DE LEGUMES MACARRAO E CARNE',
8504520: 'SOPA LEAO VELOSO',
8504521: 'SOPA DE TOMATE',
8504522: 'SOPA / CREME DE ERVILHA',
8504801: 'SALPICAO',
8505201: 'CHARUTO DE REPOLHO PRONTO',
8505202: 'CHARUTO DE REPOLHO COM CARNE BOVINA',
8505203: 'CHARUTO DE REPOLHO COM FRANGO',
8505204: 'CHARUTO DE REPOLHO COM PORCO',
8505401: 'ARROZ A GREGA',
8505501: 'ARRUMADINHO',
8505502: 'ESCONDIDINHO',
8505503: 'ARRUMADINHO DE CARNE SECA',
8505504: 'ESCONDIDINHO DE CARNE SECA',
8505505: 'ARRUMADINHO DE FRANGO OU GALINHA',
8505506: 'ESCONDIDINHO DE FRANGO OU GALINHA',
8505507: 'BOLO DE AIPIM / MANDIOCA / MACAXERA COM FRANGO OU GALINHA',
8505508: 'TORTA DE BATATA COM FRANGO',
8505509: 'ESCONDIDINHO DE CARNE',
8505510: 'BOLO DE AIPIM / MANDIOCA / MACAXERA COM CARNE',
8505511: 'TORTA DE BATATA COM CARNE',
8505513: 'ESCONDIDINHO DE BACALHAU',
8505514: 'ESCONDIDINHO DE CAMARAO',
8505601: 'BOBO DE CAMARAO',
8505602: 'BOBO DE FRUTOS DO MAR',
8505603: 'BOBO DE FRANGO OU GALINHA',
8505701: 'CARURU',
8505801: 'CUSCUZ PAULISTA',
8505802: 'CUSCUZ DE ATUM',
8505803: 'CUSCUZ DE CAMARAO',
8505804: 'CUSCUZ MINEIRO',
8505805: 'CUSCUZ DE LEGUMES',
8505806: 'CUSCUZ MARROQUINO',
8505901: 'EMPADAO',
8506001: 'FAROFA DE BANANA',
8506101: 'FEIJAO TROPEIRO',
8506201: 'GALINHA COM ARROZ',
8506301: 'GALINHADA',
8506302: 'GALINHADA CAIPIRA',
8506303: 'GALINHADA COM PEQUI',
8506401: 'MOQUECA / MUQUECA BAIANA',
8506404: 'MOQUECA / MUQUECA DE CAMARAO',
8506405: 'MOQUECA / MUQUECA DE FRUTOS DO MAR',
8506406: 'MOQUECA / MUQUECA DE LAGOSTA',
8506407: 'MOQUECA / MUQUECA DE PEIXE',
8506408: 'MOQUECA / MUQUECA NAO ESPECIFICADA',
8506501: 'OMELETE',
8506502: 'TORTILHA',
8506503: 'OMELETE COM CARNE',
8506505: 'OMELETE COM LEGUMES',
8506509: 'OMELETE COM QUEIJO E PRESUNTO',
8506511: 'OVO BENEDICT',
8506601: 'PIRAO',
8506605: 'PIRAO DE LEITE',
8506701: 'QUIBEBE',
8506801: 'QUICHE',
8506901: 'SUFLE',
8507001: 'TUTU',
8507101: 'MOQUECA / MUQUECA CAPIXABA',
8507201: 'MANICOBA',
8507301: 'CALDO VERDE',
8507401: 'ARROZ DE CUXA',
8507501: 'ANGU A BAIANA',
8507502: 'ANGU COM CARNE MOIDA E TOMATE',
8507503: 'POLENTA COM CARNE MOIDA E TOMATE',
8507601: 'CHOCOLATE',
8507701: 'GEMADA',
8507801: 'ACAI',
8507802: 'ACAI COM GUARANA E GRANOLA',
8508004: 'LASANHA / LAZANHA LIGHT',
8508017: 'PIZZA PORTUGUESA LIGHT',
8508301: 'VACA ATOLADA',
8508302: 'ATOLADO DE CARNE MOIDA',
8508303: 'COSTELA COM AIPIM / MACAXEIRA / MANDIOCA',
8508304: 'COSTELA COM BATATA',
8508305: 'ATOLADO DE CARNE SECA',
8508306: 'CARNE DE SOL ATOLADA',
8508307: 'ATOLADO DE FRANGO OU GALINHA',
8508401: 'SALADA OU VERDURA CRUA, EXCETO DE FRUTA',
8509901: 'PASTEL DE FORNO/ PASTEL ASSADO',
8510002: 'PASTEL DE FORNO INTEGRAL / PASTEL ASSADO INTEGRAL',
8510101: 'CACHORRO QUENTE COMPLETO',
8510201: 'X-CHICKEN',
8510202: 'X-FRANGO OU GALINHA',
8510301: 'X-SALADA',
8510401: 'SALADA CAESER / CESAR / CISER / CEASER',
8510501: 'SALADA DE AIPO COM MACA',
8510601: 'SALADA DE ALFACE, TOMATE E CEBOLA',
8510701: 'SALADA DE ARROZ',
8510801: 'SALADA DE ATUM',
8510901: 'SALADA DE BACALHAU COM BATATAS',
8510902: 'SALADA DE BATATA E ATUM',
8511001: 'SALADA DE FEIJAO FRADINHO',
8511003: 'SALADA DE GRAO-DE-BICO',
8511101: 'SALADA DE FOLHAS',
8511102: 'SALADA DE RUCULA E TOMATE SECO',
8511201: 'SALADA DE LEGUMES',
8511301: 'SALADA DE LENTILHAS',
8511401: 'SALADA DE TOMATE',
8511501: 'TABULE',
8511502: 'SALADA DE TRIGO',
8511701: 'SALADA DE LEGUMES E VERDURAS',
8511801: 'SALADA WALDORF',
8511901: 'LASANHA / LAZANHA DE BERINGELA',
8511902: 'LASANHA / LASANHA DE BERINGELA COM CARNE',
8512001: 'LASANHA / LAZANHA COM FRUTOS DO MAR',
8512101: 'LASANHA / LAZANHA DE FRANGO OU GALINHA',
8512201: 'LASANHA / LAZANHA DE LEGUMES AO SUGO',
8512301: 'LASANHA / LAZANHA DE QUEIJO E PRESUNTO',
8512401: 'LASANHA / LAZANHA QUATRO QUEIJOS',
8512701: 'CANELONE DE CARNE',
8512801: 'CANELONE DE FRANGO',
8512901: 'CANELONE DE QUEIJO',
8513001: 'CANELONE DE QUEIJO E PRESUNTO',
8513201: 'CANELONE DE RICOTA',
8513301: 'CANELONE DE RICOTA COM ESPINAFRE',
8570107: 'ARROZ COM FEIJAO',
8570328: 'PAO COM MANTEIGA',
8570329: 'PAO COM MARGARINA',
8570330: 'PAO COM OVO',
8570331: 'SANDUICHE DE OVO',
8571110: 'CARNE COM BATATA',
8571111: 'CARNE COM LEGUMES',
8571112: 'FRANGO COM BATATA / INHAME / BATATA BAROA / AIPIM',
8571113: 'FRANGO COM LEGUMES',
8578404: 'ABOBORA COM QUIABO',
8579002: 'ARROZ CARRETEIRO / ARROZ TROPEIRO',
8579003: 'MARIA ISABEL',
8579004: 'ARROZ DE LEITE',
8579005: 'ARROZ COM MANDIOCA',
8579006: 'ARROZ COM OVO',
8579007: 'CARNE DE BOI COM LEGUMES',
8579008: 'COSTELA COM LEGUMES',
8579009: 'ENSOPADINHO DE CARNE COM LEGUMES',
8579011: 'GUISADO /  GUIZADO DE CARNE COM LEGUMES',
8579012: 'REFOGADINHO DE CARNE COM LEGUMES',
8579015: 'GUISADO /  GUIZADO DE FRANGO OU GALINHA COM LEGUMES',
8579017: 'REFOGADINHO DE FRANGO OU GALINHA COM LEGUMES',
8579019: 'ARROZ AO MOLHO PARDO / ARROZ DE CABIDELA',
8579022: 'ARROZ CAIPIRA',
8579023: 'ARROZ CHOP SUEY',
8579024: 'ARROZ COM FRANGO E PEQUI',
8579025: 'ARROZ COM FRUTOS DO MAR / ARROZ COM PEIXE',
8579026: 'ARROZ COM JAMBU',
8579027: 'ARROZ COM LEGUMES',
8579029: 'ARROZ COM LENTILHA',
8579030: 'ARROZ COM LINGUICA',
8579031: 'ARROZ COM MACARRAO / ALETRIA / ALITRIA / CABELO DE ANJO',
8579032: 'ARROZ COM NOZES / CASTANHA / BARU',
8579033: 'ARROZ COM PEQUI',
8579034: 'ARROZ COM SALSICHA / LINGUICA',
8579035: 'ARROZ DE BROCOLIS / COUVE',
8579036: 'ARROZ DE COCO',
8579037: 'ARROZ DE FORNO',
8579038: 'ARROZ COM FRANGO / ARROZ COM CAPOTE',
8579039: 'ARROZ PIAMONTESE',
8579040: 'BACALHOADA',
8579041: 'BARREADO',
8579042: 'BATATA COM MOLHO BRANCO E QUEIJO',
8579043: 'BATATA RECHEADA',
8579045: 'BATATA SUICA / BATATA ROSTIE / ROSTI',
8579046: 'BATATA, CENOURA E CHUCHU',
8579047: 'BERINJELA / BERINGELA RECHEADA COM LEGUMES E QUEIJO',
8579048: 'BERINJELA / BERINGELA RECHEADA COM CARNE MOIDA',
8579049: 'BERINJELA / BERINGELA RECHEADA COM FRANGO OU GALINHA',
8579050: 'BIFE A PARMEGIANA',
8579052: 'BIFE DE FRANGO OU GALINHA A PARMEGIANA',
8579053: 'BOLINHA DE QUEIJO',
8579054: 'BOLINHO DE ARROZ',
8579055: 'BOLO DE BATATA COM CARNE',
8579056: 'BOLO DE BATATA DOCE COM CARNE',
8579057: 'BOLO DE BATATA COM FRANGO OU GALINHA',
8579058: 'BOLO DE BATATA DOCE COM FRANGO OU GALINHA',
8579059: 'BRUSCHETTA',
8579060: 'CABRITO COM LEGUMES',
8579061: 'CALDEIRADA DE CABRITO',
8579062: 'CALDEIRADA DE CORDEIRO',
8579063: 'CALDEIRADA DE CARNE COM LEGUMES E BATATA',
8579064: 'CARNE COZIDA COM LEGUMES E BATATA',
8579065: 'CARNE ENSOPADA COM LEGUMES E BATATA',
8579066: 'CARNE REFOGADA COM LEGUMES E BATATA',
8579067: 'ENSOPADINHO DE CARNE COM LEGUMES E BATATA',
8579069: 'ENSOPADO DE CARNE COM LEGUMES E BATATA',
8579070: 'CALDEIRADA DE FRUTOS DO MAR',
8579071: 'CALDEIRADA DE PEIXE',
8579072: 'CALDO DE PINTO',
8579073: 'CAMARAO A BAIANA',
8579076: 'FRUTO DO MAR AO LEITE DE COCO',
8579078: 'CAMARAO COM CATUPIRY',
8579079: 'CAMARAO COM MOLHO BRANCO',
8579081: 'COCKTAIL DE CAMARAO',
8579084: 'SIRI GRATINADO',
8579086: 'CAMARAO ENSOPADO COM CHUCHU / LEGUMES',
8579087: 'FRUTO DO MAR ENSOPADO COM LEGUMES',
8579088: 'CAMARAO NA ABOBORA / MORANGA',
8579090: 'CANAPE NAO ESPECIFICADO',
8579091: 'CANJIQUINHA DE MILHO COM COSTELINHA DE PORCO',
8579092: 'CAPONATA DE BERINJELA',
8579095: 'CARIBEU (CARNE SECA COM MANDIOCA)',
8579096: 'CARNE ASSADA RECHEADA',
8579099: 'CARNE RECHEADA COM LEGUMES E OU LINGUICA',
8579100: 'CARNE RECHEADA COM QUEIJO E PRESUNTO',
8579103: 'CARNE COM PEQUI',
8579105: 'CARNE DE PORCO COM LEGUMES',
8579106: 'CARNE SUINA / CARNE DE PORCO COM LEGUMES',
8579108: 'CARNE DE PORCO NO TUCUPI',
8579109: 'CARNE DE SOL COM LEGUMES',
8579110: 'CARNE SECA COM ABOBORA / LEGUMES',
8579111: 'CHARQUE COM LEGUMES',
8579113: 'CARNE DE SOL COM MACAXEIRA',
8579114: 'CARNE DESFIADA',
8579115: 'CARNE LOUCA / MALUCA',
8579117: 'CARNE NO TUCUPI',
8579119: 'CASQUINHA DE FRUTO DO MAR',
8579120: 'CASQUINHA DE CAMARAO',
8579121: 'CASQUINHA DE CARANGUEJO',
8579122: 'CASQUINHA DE MARISCOS',
8579123: 'CASQUINHA DE SIRI',
8579124: 'CESTINHA DE FRUTOS DO MAR',
8579125: 'CESTINHA DE CAMARAO',
8579128: 'CORDEIRO COM LEGUMES',
8579130: 'CREME DE ABOBORA COM CARNE',
8579131: 'CREME DE CENOURA',
8579132: 'CREME DE ESPINAFRE',
8579133: 'DOBRADINHA COM FEIJAO BRANCO',
8579135: 'EFO (BAHIA)',
8579136: 'ENSOPADINHO DE LEGUMES',
8579137: 'JARDINEIRA DE LEGUMES',
8579138: 'ENSOPADINHO DE LINGUICA COM BATATA',
8579139: 'ENSOPADINHO DE LINGUICA COM LEGUMES',
8579140: 'ENTREVERO DE PINHAO',
8579141: 'FILE DE PEIXE A PARMEGIANA',
8579142: 'FILE DE PEIXE AO CREME',
8579146: 'FRANGO CAIPIRA',
8579147: 'FRANGO ENSOPADO',
8579149: 'FRANGO OU GALINHA COM PEQUI',
8579150: 'FRANGO OU GALINHA AO MOLHO PARDO / GALINHA DE CABIDELA',
8579151: 'FRANGO OU GALINHA DE CABIDELA',
8579153: 'FRANGO OU GALINHA COM QUIABO',
8579154: 'FRANGO OU GALINHA NO TUCUPI',
8579158: 'FRANGO OU GALINHA XADREZ',
8579159: 'FRICASSE DE CARNE MOIDA',
8579160: 'FRICASSE DE FRANGO OU GALINHA',
8579161: 'FRIGIDEIRA DE PEIXE',
8579162: 'HOT FILADELFIA',
8579163: 'ISCA DE JACARE A MILANESA',
8579164: 'JARDINEIRA DE CARNE DE SOJA',
8579165: 'JARDINEIRA DE FRANGO OU GALINHA',
8579166: 'JARDINEIRA DE LEGUMES COM CARNE',
8579167: 'LAGARTO RECHEADO COM CENOURA',
8579168: 'LAGARTO RECHEADO COM LINGUICA',
8579169: 'LEGUMES A PARMEGIANA',
8579170: 'LEGUMES GRATINADOS',
8579171: 'LEGUMES RECHEADOS COM CARNE',
8579172: 'LEITAO NO TUCUPI',
8579173: 'LENTILHA COM BACON',
8579174: 'LENTILHA COM LINGUICA',
8579175: 'LINGUA BOVINA RECHEADA COM LEGUMES',
8579176: 'LOMBO RECHEADO COM LEGUMES',
8579177: 'LOMBO RECHEADO COM LINGUICA',
8579183: 'LULA ENSOPADA COM LEGUMES',
8579184: 'LULA RECHEADA COM CAMARAO',
8579185: 'MAO DE VACA',
8579186: 'MARISCADA',
8579187: 'MARISCO ENSOPADO COM LEGUMES',
8579188: 'MARISCO GRATINADO COM MOLHO BRANCO',
8579189: 'MARISCO LAMBE-LAMBE',
8579190: 'MATAMBRE RECHEADO',
8579191: 'MISSOSHIRO',
8579192: 'MOUSSE DE CAMARAO',
8579193: 'MOUSSE DE PEIXE',
8579194: 'MOUSSE DE SALMAO',
8579195: 'MUJICA / MOJICA A CUIABANA',
8579196: 'MUJICA / MOJICA DE PEIXE',
8579198: 'MUSSAKA',
8579199: 'MUSSAKA VEGETARIANA',
8579201: 'PACA ASSADA A PURURUCA',
8579202: 'PACOCA DE PINHAO',
8579204: 'PAELLA',
8579205: 'PATO NO TUCUPI',
8579206: 'PEIXADA',
8579207: 'PEIXE A PARMEGIANA',
8579209: 'PEIXE ASSADO COM LEGUMES E BATATAS',
8579210: 'PEIXE ENSOPADO COM BATATAS',
8579211: 'PEIXE ENSOPADO COM LEGUMES E BATATA',
8579212: 'PEIXE AO LEITE DE COCO',
8579213: 'PEIXE ASSADO RECHEADO COM FAROFA',
8579218: 'PEIXE GRATINADO',
8579219: 'PEIXE COM CAMARAO',
8579221: 'PETISCO DE JACARE',
8579222: 'PICADINHO DE CARNE',
8579224: 'PIMENTAO RECHEADO',
8579230: 'POLPETTONE / POLPETONE',
8579232: 'SUFLE DE LEGUMES',
8579233: 'QUICHE DE ESPINAFRE',
8579235: 'QUIBE ASSADO / QUIBE DE FORNO',
8579236: 'QUIBE CRU',
8579237: 'QUIBE VEGETARIANO',
8579238: 'QUICHE DE ALHO PORO',
8579239: 'QUICHE DE PEIXES',
8579242: 'RABADA COM AGRIAO E BATATA',
8579243: 'RATATOUILLE',
8579244: 'REFOGADINHO DE LEGUMES',
8579245: 'RISOTO DE CAMARAO',
8579246: 'RISOTO DE FRUTOS DO MAR',
8579247: 'RISOTO DE FUNGUI  (FUNGHI)',
8579248: 'RISOTO DE LEGUMES',
8579249: 'ROLINHO DE PRIMAVERA',
8579250: 'HARUMAKI DE FRUTO DO MAR',
8579251: 'HARUMAKI DE PEIXE',
8579253: 'RONDELE DE CARNE',
8579254: 'RONDELE DE FRANGO',
8579256: 'RONDELE / RONDELI / RONDELLE',
8579257: 'RONDELE DE CAMARAO',
8579259: 'RONDELE DE QUEIJO E PRESUNTO',
8579261: 'RONDELE DE RICOTA COM ESPINAFRE',
8579262: 'ROUPA VELHA (CARNE SECA, CARNE, PEIXE)',
8579266: 'SAGU AO VINHO TINTO',
8579268: 'STEAK TARTARE',
8579269: 'SUFLE DE BACALHAU',
8579270: 'SUFLE DE CAMARAO',
8579272: 'SUFLE DE FRANGO OU GALINHA',
8579280: 'TEMAKI',
8579281: 'TEMPURA DE CAMARAO',
8579282: 'TEMPURA LEGUMES',
8579283: 'TEMPURA NAO ESPECIFICADO',
8579284: 'TOMATE RECHEADO',
8579285: 'TRANCA SALGADA RECHEADA',
8579286: 'VIRADO',
8579290: 'XINXIM DE BOFE',
8579291: 'XINXIM DE FRANGO OU GALINHA',
8580001: 'PRATO FEITO',
8580101: 'MEXIDO',
8580201: 'CUSCUZ DE ARROZ',
8580301: 'SALADA DE LEGUMES, VERDURAS E FRUTAS',
8580401: 'PAO COM LINGUICA',
8580501: 'PAO COM TUCUMA',
8581001: 'CAFE COM PAO',
8581101: 'CAFE COM BOLO/ BISCOITO/ BOLACHA',
8581201: 'LEITE COM PAO OU BISCOITO/ BOLACHA',
8581301: 'SOPA INSTANTANEA',
8581401: 'MACARAO COM OVO',
8581501: 'MACARRAO COM CAMARAO',
8581502: 'MACARRAO COM FRUTOS DO MAR',
8581503: 'MACARRAO COM QUEIJO',
8581504: 'MACARRAO AO ALHO E OLEO',
8581505: 'MACARRAO COM FRANGO OU GALINHA',
8581506: 'MACARRAO COM LEGUMES',
8581507: 'MACARRAO COM LINGUICA',
8581508: 'MACARRAO COM MOLHO BRANCO',
8581509: 'MACARRAO CREMOSO / SUGO / TOMATE',
8581510: 'MACARRAO GRATINADO',
8581511: 'MACARRAO COM SALSICHA',
8581601: 'STROGONOFF / ESTROGONOFE DE CAMARAO',
8581602: 'STROGONOFF / ESTROGONOFE DE CARNE',
8581603: 'STROGONOFF / ESTROGONOFE DE CARNE DE SOJA',
8581604: 'STROGONOFF / ESTROGONOFE DE FRANGO OU GALINHA',
8581701: 'YAKISSOBA DE CARNE',
8581702: 'YAKISSOBA DE FRANGO',
8581703: 'YAKISSOBA DE FRUTOS DO MAR',
8581704: 'YAKISSOBA DE CAMARAO',
8581705: 'YAKISSOBA DE PEIXE',
8581706: 'YAKISSOBA DE LEGUMES',
8581707: 'YAKISSOBA DE SOJA',
8581801: 'CASSOULET',
8581901: 'FEIJAO COM CARNES',
8581902: 'FEIJAO COM BACON',
8581903: 'FEIJAO COM LINGUICA',
8581904: 'FEIJOADA DE FRUTOS DO MAR',
8581905: 'FEIJOADA VEGETARIANA',
8582001: 'MAIONESE DE CAMARAO',
8582101: 'TORTA CAIPIRA',
8582102: 'TORTA DE FRANGO OU GALINHA',
8582103: 'TORTA DE CARNE',
8582104: 'TORTA DE CARNE E LEGUMES',
8582105: 'TORTA DE CARNE E QUEIJO',
8582106: 'TORTA DE CARNE SECA',
8582107: 'TORTA DE BACALHAU',
8582108: 'TORTA DE CAMARAO / FRUTOS DO MAR',
8582109: 'TORTA DE PEIXE / ATUM / SARDINHA',
8582110: 'TORTA DE LEGUMES',
8582111: 'TORTA DE PRESUNTO E QUEIJO',
8582112: 'TORTA DE QUEIJO / RICOTA',
8582201: 'TORTA CAPIXABA',
8582301: 'ROCAMBOLE SALGADO',
8582302: 'ROCAMBOLE DE CARNE',
8582303: 'ROCAMBOLE DE FRANGO OU GALINHA',
8800109: 'PALMA'    
}

# %%
#Traduzindo informações das colunas categóricas:
consumo['V9001'] = consumo.V9001.map(col_V9001)
consumo['V9016'] = consumo.V9016.map(col_V9016)
consumo['V9015'] = consumo.V9015.map(col_V9015)
consumo['V9018'] = consumo.V9018.map(col_V9018)
consumo['V9019'] = consumo.V9019.map(col_V9019)
consumo['V9020'] = consumo.V9020.map(col_V9020)
consumo['V9021'] = consumo.V9021.map(col_V9021)
consumo['V9022'] = consumo.V9022.map(col_V9022)
consumo['V9023'] = consumo.V9023.map(col_V9023)
consumo['V9024'] = consumo.V9024.map(col_V9024)
consumo['V9025'] = consumo.V9025.map(col_V9025)
consumo['V9026'] = consumo.V9026.map(col_V9026)
consumo['V9027'] = consumo.V9027.map(col_V9027)
consumo['V9028'] = consumo.V9028.map(col_V9028)
consumo['V9029'] = consumo.V9029.map(col_V9019)
consumo['V9030'] = consumo.V9030.map(col_V9030)
consumo['COD_PREPARACAO_FINAL'] = consumo.COD_PREPARACAO_FINAL.map(col_PrepFinal)

# %%
#Criando 4 datasets para Minas Gerais baseados no período de alimentação para aplicar o apriori em cada um:

#Café da manhã:
dataset_cafe = consumo.query('V9015 == "Café da manhã"')
dataset_cafe = dataset_cafe.query('UF == "31"')
df_cafemg = dataset_cafe[['Família', 'V9001']]

#Almoço:
dataset_almoco = consumo.query('V9015 == "Almoço"')
dataset_almoco = dataset_almoco.query('UF == "31"')
df_almocomg = dataset_almoco[['Família', 'V9001']]

#Jantar
dataset_jantar = consumo.query('V9015 == "Jantar"')
dataset_jantar = dataset_jantar.query('UF == "31"')
df_jantarmg = dataset_jantar[['Família', 'V9001']]

#Lanche
dataset_lanche = consumo.query('V9015 == "Lanche"')
dataset_lanche = dataset_lanche.query('UF == "31"')
df_lanchemg = dataset_lanche[['Família', 'V9001']]

# %%
#Criando 4 datasets para São Paulo baseados no período de alimentação para aplicar o apriori em cada um:

#Café da manhã:
dataset_cafe = consumo.query('V9015 == "Café da manhã"')
dataset_cafe = dataset_cafe.query('UF == "35"')
df_cafesp = dataset_cafe[['Família', 'V9001']]

#Almoço:
dataset_almoco = consumo.query('V9015 == "Almoço"')
dataset_almoco = dataset_almoco.query('UF == "35"')
df_almocosp = dataset_almoco[['Família', 'V9001']]

#Jantar
dataset_jantar = consumo.query('V9015 == "Jantar"')
dataset_jantar = dataset_jantar.query('UF == "35"')
df_jantarsp = dataset_jantar[['Família', 'V9001']]

#Lanche
dataset_lanche = consumo.query('V9015 == "Lanche"')
dataset_lanche = dataset_lanche.query('UF == "35"')
df_lanchesp = dataset_lanche[['Família', 'V9001']]

# %%
#Criando 4 datasets para Bahia baseados no período de alimentação para aplicar o apriori em cada um:

#Café da manhã:
dataset_cafe = consumo.query('V9015 == "Café da manhã"')
dataset_cafe = dataset_cafe.query('UF == "29"')
df_cafeba = dataset_cafe[['Família', 'V9001']]

#Almoço:
dataset_almoco = consumo.query('V9015 == "Almoço"')
dataset_almoco = dataset_almoco.query('UF == "29"')
df_almocoba = dataset_almoco[['Família', 'V9001']]

#Jantar
dataset_jantar = consumo.query('V9015 == "Jantar"')
dataset_jantar = dataset_jantar.query('UF == "29"')
df_jantarba = dataset_jantar[['Família', 'V9001']]

#Lanche
dataset_lanche = consumo.query('V9015 == "Lanche"')
dataset_lanche = dataset_lanche.query('UF == "29"')
df_lancheba = dataset_lanche[['Família', 'V9001']]

# %%
#Criando 4 datasets para o Rio Grande do Sul baseados no período de alimentação para aplicar o apriori em cada um:

#Café da manhã:
dataset_cafe = consumo.query('V9015 == "Café da manhã"')
dataset_cafe = dataset_cafe.query('UF == "43"')
df_cafers = dataset_cafe[['Família', 'V9001']]

#Almoço:
dataset_almoco = consumo.query('V9015 == "Almoço"')
dataset_almoco = dataset_almoco.query('UF == "43"')
df_almocors = dataset_almoco[['Família', 'V9001']]

#Jantar
dataset_jantar = consumo.query('V9015 == "Jantar"')
dataset_jantar = dataset_jantar.query('UF == "43"')
df_jantarrs = dataset_jantar[['Família', 'V9001']]

#Lanche
dataset_lanche = consumo.query('V9015 == "Lanche"')
dataset_lanche = dataset_lanche.query('UF == "43"')
df_lanchers = dataset_lanche[['Família', 'V9001']]

# %%
#Criando 4 datasets para o Goiás baseados no período de alimentação para aplicar o apriori em cada um:

#Café da manhã:
dataset_cafe = consumo.query('V9015 == "Café da manhã"')
dataset_cafe = dataset_cafe.query('UF == "52"')
df_cafego = dataset_cafe[['Família', 'V9001']]

#Almoço:
dataset_almoco = consumo.query('V9015 == "Almoço"')
dataset_almoco = dataset_almoco.query('UF == "52"')
df_almocogo = dataset_almoco[['Família', 'V9001']]

#Jantar
dataset_jantar = consumo.query('V9015 == "Jantar"')
dataset_jantar = dataset_jantar.query('UF == "52"')
df_jantargo = dataset_jantar[['Família', 'V9001']]

#Lanche
dataset_lanche = consumo.query('V9015 == "Lanche"')
dataset_lanche = dataset_lanche.query('UF == "52"')
df_lanchego = dataset_lanche[['Família', 'V9001']]

# %%
#Criando 4 datasets para o Pará baseados no período de alimentação para aplicar o apriori em cada um:

#Café da manhã:
dataset_cafe = consumo.query('V9015 == "Café da manhã"')
dataset_cafe = dataset_cafe.query('UF == "15"')
df_cafepa = dataset_cafe[['Família', 'V9001']]

#Almoço:
dataset_almoco = consumo.query('V9015 == "Almoço"')
dataset_almoco = dataset_almoco.query('UF == "15"')
df_almocopa = dataset_almoco[['Família', 'V9001']]

#Jantar
dataset_jantar = consumo.query('V9015 == "Jantar"')
dataset_jantar = dataset_jantar.query('UF == "15"')
df_jantarpa = dataset_jantar[['Família', 'V9001']]

#Lanche
dataset_lanche = consumo.query('V9015 == "Lanche"')
dataset_lanche = dataset_lanche.query('UF == "15"')
df_lanchepa = dataset_lanche[['Família', 'V9001']]

# %%
#Criando listas de consumo para cada família:

#São Paulo: Sudeste
df_cafesp = pd.crosstab(df_cafesp.Família, df_cafesp.V9001)
df_almocosp = pd.crosstab(df_almocosp.Família, df_almocosp.V9001)
df_jantarsp = pd.crosstab(df_jantarsp.Família, df_jantarsp.V9001)
df_lanchesp = pd.crosstab(df_lanchesp.Família, df_lanchesp.V9001)

#Minas Gerais: Sudeste
df_cafemg = pd.crosstab(df_cafemg.Família, df_cafemg.V9001)
df_almocomg = pd.crosstab(df_almocomg.Família, df_almocomg.V9001)
df_jantarmg = pd.crosstab(df_jantarmg.Família, df_jantarmg.V9001)
df_lanchemg = pd.crosstab(df_lanchemg.Família, df_lanchemg.V9001)

#Bahia: Nordeste
df_cafeba = pd.crosstab(df_cafeba.Família, df_cafeba.V9001)
df_almocoba = pd.crosstab(df_almocoba.Família, df_almocoba.V9001)
df_jantarba = pd.crosstab(df_jantarba.Família, df_jantarba.V9001)
df_lancheba = pd.crosstab(df_lancheba.Família, df_lancheba.V9001)

#Rio Grande do Sul: Sul
df_cafers = pd.crosstab(df_cafers.Família, df_cafers.V9001)
df_almocors = pd.crosstab(df_almocors.Família, df_almocors.V9001)
df_jantarrs = pd.crosstab(df_jantarrs.Família, df_jantarrs.V9001)
df_lanchers = pd.crosstab(df_lanchers.Família, df_lanchers.V9001)

#Goiás: Centro-Oeste
df_cafego = pd.crosstab(df_cafego.Família, df_cafego.V9001)
df_almocogo = pd.crosstab(df_almocogo.Família, df_almocogo.V9001)
df_jantargo = pd.crosstab(df_jantargo.Família, df_jantargo.V9001)
df_lanchego = pd.crosstab(df_lanchego.Família, df_lanchego.V9001)

#Pará: Norte
df_cafepa = pd.crosstab(df_cafepa.Família, df_cafepa.V9001)
df_almocopa = pd.crosstab(df_almocopa.Família, df_almocopa.V9001)
df_jantarpa = pd.crosstab(df_jantarpa.Família, df_jantarpa.V9001)
df_lanchepa = pd.crosstab(df_lanchepa.Família, df_lanchepa.V9001)

# %%
#Tratando valores maiores que 1 em cada dataset:

#Minas Gerais:
df_cafemg[df_cafemg>1] = 1
df_almocomg[df_almocomg>1] = 1
df_jantarmg[df_jantarmg>1] = 1
df_lanchemg[df_lanchemg>1] = 1

#São Paulo:
df_cafesp[df_cafesp>1] = 1
df_almocosp[df_almocosp>1] = 1
df_jantarsp[df_jantarsp>1] = 1
df_lanchesp[df_lanchesp>1] = 1

#Bahia:
df_cafeba[df_cafeba>1] = 1
df_almocoba[df_almocoba>1] = 1
df_jantarba[df_jantarba>1] = 1
df_lancheba[df_lancheba>1] = 1

#Rio Grande do Sul:
df_cafers[df_cafers>1] = 1
df_almocors[df_almocors>1] = 1
df_jantarrs[df_jantarrs>1] = 1
df_lanchers[df_lanchers>1] = 1

#Goiás:
df_cafego[df_cafego>1] = 1
df_almocogo[df_almocogo>1] = 1
df_jantargo[df_jantargo>1] = 1
df_lanchego[df_lanchego>1] = 1

#Pará:
df_cafepa[df_cafepa>1] = 1
df_almocopa[df_almocopa>1] = 1
df_jantarpa[df_jantarpa>1] = 1
df_lanchepa[df_lanchepa>1] = 1

# %%
#Importando bibliotecas para rodar o apriori:
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
#Apriori para períodos em São Paulo:

#Café da manhã:
frequent_itemsets_cafesp = apriori(df_cafesp, min_support=0.1,use_colnames=True)
rules_cafesp = association_rules(frequent_itemsets_cafesp, metric="lift", min_threshold=1)

#Almoço:
frequent_itemsets_almocosp = apriori(df_almocosp, min_support=0.1,use_colnames=True)
rules_almocosp = association_rules(frequent_itemsets_almocosp, metric="lift", min_threshold=1)

#Jantar:
frequent_itemsets_jantarsp = apriori(df_jantarsp, min_support=0.1,use_colnames=True)
rules_jantarsp = association_rules(frequent_itemsets_jantarsp, metric="lift", min_threshold=1)

#Lanche:
frequent_itemsets_lanchesp = apriori(df_lanchesp, min_support=0.1,use_colnames=True)
rules_lanchesp = association_rules(frequent_itemsets_lanchesp, metric="lift", min_threshold=1)

# %%
#Apriori para períodos em Minas Gerais:

#Café da manhã:
frequent_itemsets_cafemg = apriori(df_cafemg, min_support=0.1,use_colnames=True)
rules_cafemg = association_rules(frequent_itemsets_cafemg, metric="lift", min_threshold=1)

#Almoço:
frequent_itemsets_almocomg = apriori(df_almocosp, min_support=0.1,use_colnames=True)
rules_almocomg = association_rules(frequent_itemsets_almocomg, metric="lift", min_threshold=1)

#Jantar:
frequent_itemsets_jantarmg = apriori(df_jantarsp, min_support=0.1,use_colnames=True)
rules_jantarmg = association_rules(frequent_itemsets_jantarmg, metric="lift", min_threshold=1)

#Lanche:
frequent_itemsets_lanchemg = apriori(df_lanchesp, min_support=0.1,use_colnames=True)
rules_lanchemg = association_rules(frequent_itemsets_lanchemg, metric="lift", min_threshold=1)

# %%
#Apriori para períodos em Bahia:

#Café da manhã:
frequent_itemsets_cafeba = apriori(df_cafeba, min_support=0.1,use_colnames=True)
rules_cafeba = association_rules(frequent_itemsets_cafeba, metric="lift", min_threshold=1)

#Almoço:
frequent_itemsets_almocoba = apriori(df_almocoba, min_support=0.1,use_colnames=True)
rules_almocoba = association_rules(frequent_itemsets_almocoba, metric="lift", min_threshold=1)

#Jantar:
frequent_itemsets_jantarba = apriori(df_jantarba, min_support=0.1,use_colnames=True)
rules_jantarba = association_rules(frequent_itemsets_jantarba, metric="lift", min_threshold=1)

#Lanche:
frequent_itemsets_lancheba = apriori(df_lancheba, min_support=0.1,use_colnames=True)
rules_lancheba = association_rules(frequent_itemsets_lancheba, metric="lift", min_threshold=1)

# %%
#Apriori para períodos no Rio Grande do Sul:

#Café da manhã:
frequent_itemsets_cafers = apriori(df_cafers, min_support=0.1,use_colnames=True)
rules_cafers = association_rules(frequent_itemsets_cafers, metric="lift", min_threshold=1)

#Almoço:
frequent_itemsets_almocors = apriori(df_almocors, min_support=0.1,use_colnames=True)
rules_almocors = association_rules(frequent_itemsets_almocors, metric="lift", min_threshold=1)

#Jantar:
frequent_itemsets_jantarrs = apriori(df_jantarrs, min_support=0.1,use_colnames=True)
rules_jantarrs = association_rules(frequent_itemsets_jantarrs, metric="lift", min_threshold=1)

#Lanche:
frequent_itemsets_lanchers = apriori(df_lanchers, min_support=0.1,use_colnames=True)
rules_lanchers = association_rules(frequent_itemsets_lanchers, metric="lift", min_threshold=1)

# %%
#Apriori para períodos em Goiás:

#Café da manhã:
frequent_itemsets_cafego = apriori(df_cafego, min_support=0.1,use_colnames=True)
rules_cafego = association_rules(frequent_itemsets_cafego, metric="lift", min_threshold=1)

#Almoço:
frequent_itemsets_almocogo = apriori(df_almocogo, min_support=0.1,use_colnames=True)
rules_almocogo = association_rules(frequent_itemsets_almocogo, metric="lift", min_threshold=1)

#Jantar:
frequent_itemsets_jantargo = apriori(df_jantargo, min_support=0.1,use_colnames=True)
rules_jantargo = association_rules(frequent_itemsets_jantargo, metric="lift", min_threshold=1)

#Lanche:
frequent_itemsets_lanchego = apriori(df_lanchego, min_support=0.1,use_colnames=True)
rules_lanchego = association_rules(frequent_itemsets_lanchego, metric="lift", min_threshold=1)

# %%
#Apriori para períodos no Pará:

#Café da manhã:
frequent_itemsets_cafepa = apriori(df_cafepa, min_support=0.1,use_colnames=True)
rules_cafepa = association_rules(frequent_itemsets_cafepa, metric="lift", min_threshold=1)

#Almoço:
frequent_itemsets_almocopa = apriori(df_almocopa, min_support=0.1,use_colnames=True)
rules_almocopa = association_rules(frequent_itemsets_almocopa, metric="lift", min_threshold=1)

#Jantar:
frequent_itemsets_jantarpa = apriori(df_jantarpa, min_support=0.1,use_colnames=True)
rules_jantarpa = association_rules(frequent_itemsets_jantarpa, metric="lift", min_threshold=1)

#Lanche:
frequent_itemsets_lanchepa = apriori(df_lanchepa, min_support=0.1,use_colnames=True)
rules_lanchepa = association_rules(frequent_itemsets_lanchepa, metric="lift", min_threshold=1)

# %%
#Aplicando filtro no apriori para casos de maiores ocorrências em São Paulo:
cafesp = rules_cafesp[(rules_cafesp['lift'] >= 1.0) & (rules_cafesp['confidence'] >= 0.6)]
almocosp = rules_almocosp[(rules_almocosp['lift'] >= 1.0) & (rules_almocosp['confidence'] >= 0.6)]
jantarsp = rules_jantarsp[(rules_jantarsp['lift'] >= 1.0) & (rules_jantarsp['confidence'] >= 0.6)]
lanchesp = rules_lanchesp[(rules_lanchesp['lift'] >= 1.0) & (rules_lanchesp['confidence'] >= 0.6)]

# %%
#Aplicando filtro no apriori para casos de maiores ocorrências em Minas Gerais:
cafemg = rules_cafemg[(rules_cafemg['lift'] >= 1.0) & (rules_cafemg['confidence'] >= 0.6)]
almocomg = rules_almocomg[(rules_almocomg['lift'] >= 1.0) & (rules_almocomg['confidence'] >= 0.6)]
jantarmg = rules_jantarmg[(rules_jantarmg['lift'] >= 1.0) & (rules_jantarmg['confidence'] >= 0.6)]
lanchemg = rules_lanchemg[(rules_lanchemg['lift'] >= 1.0) & (rules_lanchemg['confidence'] >= 0.6)]

# %%
#Aplicando filtro no apriori para casos de maiores ocorrências na Bahia:
cafeba = rules_cafeba[(rules_cafeba['lift'] >= 1.0) & (rules_cafeba['confidence'] >= 0.6)]
almocoba = rules_almocoba[(rules_almocoba['lift'] >= 1.0) & (rules_almocoba['confidence'] >= 0.6)]
jantarba = rules_jantarba[(rules_jantarba['lift'] >= 1.0) & (rules_jantarba['confidence'] >= 0.6)]
lancheba = rules_lancheba[(rules_lancheba['lift'] >= 1.0) & (rules_lancheba['confidence'] >= 0.6)]

# %%
#Aplicando filtro no apriori para casos de maiores ocorrências no Rio Grande do Sul:
cafers = rules_cafers[(rules_cafers['lift'] >= 1.0) & (rules_cafers['confidence'] >= 0.6)]
almocors = rules_almocors[(rules_almocors['lift'] >= 1.0) & (rules_almocors['confidence'] >= 0.6)]
jantarrs = rules_jantarrs[(rules_jantarrs['lift'] >= 1.0) & (rules_jantarrs['confidence'] >= 0.6)]
lanchers = rules_lanchers[(rules_lanchers['lift'] >= 1.0) & (rules_lanchers['confidence'] >= 0.6)]

# %%
#Aplicando filtro no apriori para casos de maiores ocorrências em Goiás:
cafego = rules_cafego[(rules_cafego['lift'] >= 1.0) & (rules_cafego['confidence'] >= 0.6)]
almocogo = rules_almocogo[(rules_almocogo['lift'] >= 1.0) & (rules_almocogo['confidence'] >= 0.6)]
jantargo = rules_jantargo[(rules_jantargo['lift'] >= 1.0) & (rules_jantargo['confidence'] >= 0.6)]
lanchego = rules_lanchego[(rules_lanchego['lift'] >= 1.0) & (rules_lanchego['confidence'] >= 0.6)]

# %%
#Aplicando filtro no apriori para casos de maiores ocorrências no Pará:
cafepa = rules_cafepa[(rules_cafepa['lift'] >= 1.0) & (rules_cafepa['confidence'] >= 0.6)]
almocopa = rules_almocopa[(rules_almocopa['lift'] >= 1.0) & (rules_almocopa['confidence'] >= 0.6)]
jantarpa = rules_jantarpa[(rules_jantarpa['lift'] >= 1.0) & (rules_jantarpa['confidence'] >= 0.6)]
lanchepa = rules_lanchepa[(rules_lanchepa['lift'] >= 1.0) & (rules_lanchepa['confidence'] >= 0.6)]

# %%
#Organizando dataframe por ordem crescente para São Paulo:
cafesp.sort_values(by = 'confidence', ascending = False).head()
# Out:
#                                            antecedents  \
# 144  (MARGARINA COM OU SEM SAL, CAFE COM LEITE, PAO...
# 88    (MARGARINA COM OU SEM SAL, CAFE COM LEITE, CAFE)
# 98                 (CAFE COM LEITE, PAO FRANCES, CAFE)
# 109                        (ACUCAR, PAO FRANCES, CAFE)
# 147        (ACUCAR, CAFE COM LEITE, PAO FRANCES, CAFE)
#
#                     consequents  antecedent support  consequent support  \
# 144                    (ACUCAR)            0.138193            0.719058
# 88                     (ACUCAR)            0.179195            0.719058
# 98                     (ACUCAR)            0.156416            0.719058
# 109  (MARGARINA COM OU SEM SAL)            0.248292            0.540623
# 147  (MARGARINA COM OU SEM SAL)            0.143508            0.540623
#
#       support  confidence      lift  leverage  conviction
# 144  0.129081    0.934066  1.299012  0.029712    4.260947
# 88   0.165528    0.923729  1.284637  0.036676    3.683456
# ...

# %%
#Organizando dataframe por ordem crescente para Minas Gerais:
cafemg.sort_values(by = 'confidence', ascending = False).head()
# Out:
#                            antecedents consequents  antecedent support  \
# 53                (PAO DE SAL, ACUCAR)      (CAFE)            0.119537
# 34                      (AGUA, ACUCAR)      (CAFE)            0.160026
# 20                     (PAO DE QUEIJO)      (CAFE)            0.122751
# 22                        (PAO DE SAL)      (CAFE)            0.185090
# 46  (MARGARINA COM OU SEM SAL, ACUCAR)      (CAFE)            0.258355
#
#     consequent support   support  confidence      lift  leverage  conviction
# 53            0.753213  0.109897    0.919355  1.220577  0.019860    3.060154
# 34            0.753213  0.141388    0.883534  1.173020  0.020855    2.118961
# 20            0.753213  0.107969    0.879581  1.167772  0.015512    2.049402
# 22            0.753213  0.158740    0.857639  1.138640  0.019328    1.733526
# 46            0.753213  0.221080    0.855721  1.136094  0.026483    1.710487

# %%
#Organizando dataframe por ordem crescente para a Bahia:
cafeba.sort_values(by = 'confidence', ascending = False).head()
# Out:
#                                            antecedents consequents  \
# 360  (MARGARINA COM OU SEM SAL, PAO DE SAL, CAFE CO...    (ACUCAR)
# 329   (MARGARINA COM OU SEM SAL, CAFE COM LEITE, CAFE)    (ACUCAR)
# 416  (AGUA, MARGARINA COM OU SEM SAL, CAFE COM LEIT...    (ACUCAR)
# 161             (MARGARINA COM OU SEM SAL, PAO DE SAL)    (ACUCAR)
# 125                                 (PAO DE SAL, CAFE)    (ACUCAR)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 360            0.107042            0.792488  0.103286    0.964912  1.217573
# 329            0.174648            0.792488  0.164319    0.940860  1.187223
# 416            0.146479            0.792488  0.137089    0.935897  1.180961
# 161            0.144601            0.792488  0.135211    0.935065  1.179910
# 125            0.115493            0.792488  0.107981    0.934959  1.179777
#
#      leverage  conviction
# 360  0.018457    5.914085
# 329  0.025913    3.508835
# ...

# %%
#Organizando dataframe por ordem crescente para o Rio Grande do Sul:
cafers.sort_values(by = 'confidence', ascending = False).head()
# Out:
#                                           antecedents consequents  \
# 141  (MARGARINA COM OU SEM SAL, CAFE COM LEITE, CAFE)    (ACUCAR)
# 62                              (PAO CACETINHO, CAFE)    (ACUCAR)
# 117            (AGUA, MARGARINA COM OU SEM SAL, CAFE)    (ACUCAR)
# 48                             (CAFE COM LEITE, CAFE)    (ACUCAR)
# 89          (MARGARINA COM OU SEM SAL, PAO CACETINHO)    (ACUCAR)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 141            0.136821            0.678068  0.127767    0.933824  1.377182
# 62             0.133803            0.678068  0.120724    0.902256  1.330626
# 117            0.116700            0.678068  0.104628    0.896552  1.322214
# 48             0.223340            0.678068  0.199195    0.891892  1.315342
# 89             0.155936            0.678068  0.138833    0.890323  1.313028
#
#      leverage  conviction
# 141  0.034993    4.864744
# 62   0.029997    3.293608
# 117  0.025497    3.112005
# ...

# %%
#Organizando dataframe por ordem crescente para o Goiás:
cafego.sort_values(by = 'confidence', ascending = False).head()
# Out:
#                       antecedents                 consequents  \
# 62  (CAFE COM LEITE, PAO FRANCES)  (MARGARINA COM OU SEM SAL)
# 28        (ACUCAR, PAO DE QUEIJO)                      (CAFE)
# 46          (ACUCAR, PAO FRANCES)  (MARGARINA COM OU SEM SAL)
# 69    (ACUCAR, PAO FRANCES, CAFE)  (MARGARINA COM OU SEM SAL)
# 34          (ACUCAR, PAO FRANCES)                      (CAFE)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 62            0.146631            0.375165  0.136063    0.927928  2.473385
# 28            0.163804            0.756935  0.145310    0.887097  1.171959
# 46            0.260238            0.375165  0.220608    0.847716  2.259580
# 69            0.219287            0.375165  0.184941    0.843373  2.248006
# 34            0.260238            0.756935  0.219287    0.842640  1.113225
#
#     leverage  conviction
# 62  0.081052    8.669584
# 28  0.021321    2.152859
# 46  0.122976    4.103082
# 69  0.102672    3.989330
# ...

# %%
#Organizando dataframe por ordem crescente para o Pará:
cafepa.sort_values(by = 'confidence', ascending = False).head()
# Out:
#                                antecedents                 consequents  \
# 292   (PAO CARECA, ACUCAR, CAFE COM LEITE)  (MARGARINA COM OU SEM SAL)
# 103                   (PAO CARECA, ACUCAR)  (MARGARINA COM OU SEM SAL)
# 307  (ACUCAR, CAFE COM LEITE, PAO FRANCES)  (MARGARINA COM OU SEM SAL)
# 167           (PAO CARECA, CAFE COM LEITE)  (MARGARINA COM OU SEM SAL)
# 32                            (PAO CARECA)  (MARGARINA COM OU SEM SAL)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 292            0.108955            0.528358  0.104478    0.958904  1.814875
# 103            0.132836            0.528358  0.126866    0.955056  1.807592
# 307            0.117910            0.528358  0.110448    0.936709  1.772867
# 167            0.129851            0.528358  0.120896    0.931034  1.762127
# 32             0.159701            0.528358  0.147761    0.925234  1.751148
#
#      leverage  conviction
# 292  0.046910   11.476617
# 103  0.056681   10.494030
# ...

# %%
#Criando dataset final para São Paulo:
df_finalsp = pd.concat([cafesp, almocosp, jantarsp, lanchesp])

# %%
#Criando dataset final para Minas Gerais:
df_finalmg = pd.concat([cafemg, almocomg, jantarmg, lanchemg])

# %%
#Criando dataset final para Bahia:
df_finalba = pd.concat([cafeba, almocoba, jantarba, lancheba])

# %%
#Criando dataset final para o Rio Grande do Sul:
df_finalrs = pd.concat([cafers, almocors, jantarrs, lanchers])

# %%
#Criando dataset final para Goiás:
df_finalgo = pd.concat([cafego, almocogo, jantargo, lanchego])

# %%
#Criando dataset final para o Pará:
df_finalpa = pd.concat([cafepa, almocopa, jantarpa, lanchepa])

# %%
#Transformando palavras da tabela final de recomendações de São Paulo para string:
df_finalsp["antecedents"] = df_finalsp["antecedents"].apply(lambda x: ', '.join(list(x))).astype("unicode")
df_finalsp["consequents"] = df_finalsp["consequents"].apply(lambda x: ', '.join(list(x))).astype("unicode")

# %%
#Transformando palavras da tabela final de recomendações de Minas Gerais para string:
df_finalmg["antecedents"] = df_finalmg["antecedents"].apply(lambda x: ', '.join(list(x))).astype("unicode")
df_finalmg["consequents"] = df_finalmg["consequents"].apply(lambda x: ', '.join(list(x))).astype("unicode")

# %%
#Transformando palavras da tabela final de recomendações de Bahia para string:
df_finalba["antecedents"] = df_finalba["antecedents"].apply(lambda x: ', '.join(list(x))).astype("unicode")
df_finalba["consequents"] = df_finalba["consequents"].apply(lambda x: ', '.join(list(x))).astype("unicode")

# %%
#Transformando palavras da tabela final de recomendações do Rio Grande do Sul para string:
df_finalrs["antecedents"] = df_finalrs["antecedents"].apply(lambda x: ', '.join(list(x))).astype("unicode")
df_finalrs["consequents"] = df_finalrs["consequents"].apply(lambda x: ', '.join(list(x))).astype("unicode")

# %%
#Transformando palavras da tabela final de recomendações de Goiás para string:
df_finalgo["antecedents"] = df_finalgo["antecedents"].apply(lambda x: ', '.join(list(x))).astype("unicode")
df_finalgo["consequents"] = df_finalgo["consequents"].apply(lambda x: ', '.join(list(x))).astype("unicode")

# %%
#Transformando palavras da tabela final de recomendações do Pará para string:
df_finalpa["antecedents"] = df_finalpa["antecedents"].apply(lambda x: ', '.join(list(x))).astype("unicode")
df_finalpa["consequents"] = df_finalpa["consequents"].apply(lambda x: ', '.join(list(x))).astype("unicode")

# %%
df = df_finalsp[df_finalsp['consequents'].str.contains(',')]
df_drop = df[['antecedents','consequents']]
df_drop.index
lista_remover = df_drop.index.to_list()
df_final_sp = df_finalsp.drop(lista_remover, axis = 0)
df_final_sp.sample(10)
# Out:
#                                antecedents               consequents  \
# 24                MARGARINA COM OU SEM SAL                      CAFE
# 106                   ALFACE, FEIJAO PRETO              ARROZ BRANCO
# 82                    ACUCAR, ARROZ BRANCO              FEIJAO PRETO
# 18                            AGUA MINERAL                      CAFE
# 14                     ADOCANTE ARTIFICIAL            CAFE COM LEITE
# 56                  ACUCAR, CAFE COM LEITE  MARGARINA COM OU SEM SAL
# 118                     FEIJAO PRETO, BIFE              ARROZ BRANCO
# 76   MARGARINA COM OU SEM SAL, PAO FRANCES                      CAFE
# 11                             PAO FRANCES                    ACUCAR
# 101             AGUA MINERAL, FEIJAO PRETO              ARROZ BRANCO
#
#      antecedent support  consequent support   support  confidence      lift  \
# 24             0.540623            0.596052  0.340167    0.629213  1.055636
# ...

# %%
df = df_finalmg[df_finalmg['consequents'].str.contains(',')]
df_drop = df[['antecedents','consequents']]
df_drop.index
lista_remover = df_drop.index.to_list()
df_final_mg = df_finalmg.drop(lista_remover, axis = 0)
df_final_mg.sample(100)
# Out:
#                                            antecedents  \
# 20                                       PAO DE QUEIJO
# 78                                 ACUCAR, PAO FRANCES
# 34                                        AGUA, ACUCAR
# 44                                CAFE COM LEITE, CAFE
# 16                                    BISCOITO SALGADO
# 135                    ARROZ BRANCO, FRANGO EM PEDACOS
# 123             MARGARINA COM OU SEM SAL, ACUCAR, CAFE
# 26                                ACUCAR, ARROZ BRANCO
# 167                         ACUCAR, ARROZ BRANCO, CAFE
# 11                                      CAFE COM LEITE
# 5                                       CAFE COM LEITE
# 24                                     AZEITE DE OLIVA
# 3                                                 CAFE
# 32                                  AGUA, ARROZ BRANCO
# 7                                          PAO FRANCES
# 19                                               ARROZ
# ...

# %%
df = df_finalba[df_finalba['consequents'].str.contains(',')]
df_drop = df[['antecedents','consequents']]
df_drop.index
lista_remover = df_drop.index.to_list()
df_final_ba = df_finalba.drop(lista_remover, axis = 0)
df_final_ba.sample(10)
# Out:
#                                    antecedents               consequents  \
# 234       MARGARINA COM OU SEM SAL, PAO DE SAL            CAFE COM LEITE
# 735          ARROZ, CARNE BOVINA, FEIJAO PRETO                      AGUA
# 3                                         CAFE                    ACUCAR
# 190                       ACUCAR, ARROZ BRANCO              FEIJAO PRETO
# 473  AGUA, ACUCAR, CAFE COM LEITE, PAO FRANCES  MARGARINA COM OU SEM SAL
# 263                         AGUA, CARNE BOVINA                     ARROZ
# 540                   AGUA, FEIJAO PRETO, CAFE                    ACUCAR
# 10                    MARGARINA COM OU SEM SAL                    ACUCAR
# 721                  ARROZ, CAFE, FEIJAO PRETO                      AGUA
# 1                                       ACUCAR                      AGUA
#
#      antecedent support  consequent support   support  confidence      lift  \
# 234            0.144601            0.588732  0.107042    0.740260  1.257379
# ...

# %%
df = df_finalrs[df_finalrs['consequents'].str.contains(',')]
df_drop = df[['antecedents','consequents']]
df_drop.index
lista_remover = df_drop.index.to_list()
df_final_rs = df_finalrs.drop(lista_remover, axis = 0)
df_final_rs.sample(10)
# Out:
#                           antecedents   consequents  antecedent support  \
# 66                           MANDIOCA  FEIJAO PRETO            0.122790
# 63                          CHIMARRAO  FEIJAO PRETO            0.221022
# 51                               SUCO  ARROZ BRANCO            0.120825
# 54   MARGARINA COM OU SEM SAL, ACUCAR          CAFE            0.364185
# 176        AGUA, ACUCAR, ARROZ BRANCO  FEIJAO PRETO            0.122790
# 13                     CAFE COM LEITE          AGUA            0.276303
# 95                       AGUA, ALFACE  ARROZ BRANCO            0.152259
# 9                         PAO FRANCES        ACUCAR            0.135815
# 51               ACUCAR, FEIJAO PRETO          AGUA            0.147493
# 41                         AGUA, CAFE        ACUCAR            0.154376
#
#      consequent support   support  confidence      lift  leverage  conviction
# 66             0.685658  0.104126    0.848000  1.236768  0.019934    2.068038
# ...

# %%
df = df_finalgo[df_finalgo['consequents'].str.contains(',')]
df_drop = df[['antecedents','consequents']]
df_drop.index
lista_remover = df_drop.index.to_list()
df_final_go = df_finalgo.drop(lista_remover, axis = 0)
df_final_go.sample(10)
# Out:
#                                        antecedents   consequents  \
# 194                     ACUCAR, FEIJAO PRETO, CAFE  ARROZ BRANCO
# 0                                           ACUCAR          CAFE
# 21                                            CAFE  ARROZ BRANCO
# 92                      AGUA MINERAL, ARROZ BRANCO  FEIJAO PRETO
# 26                                    ARROZ BRANCO  FEIJAO PRETO
# 1                                             CAFE        ACUCAR
# 66   MARGARINA COM OU SEM SAL, ACUCAR, PAO FRANCES          CAFE
# 148                   CARNE DE PORCO, FEIJAO PRETO  ARROZ BRANCO
# 22                MARGARINA COM OU SEM SAL, ACUCAR          CAFE
# 10                                            AGUA  FEIJAO PRETO
#
#      antecedent support  consequent support   support  confidence      lift  \
# 194            0.188144            0.798969  0.162371    0.863014  1.080159
# 0              0.441860            0.476744  0.332849    0.753289  1.580071
# ...

# %%
df = df_finalpa[df_finalpa['consequents'].str.contains(',')]
df_drop = df[['antecedents','consequents']]
df_drop.index
lista_remover = df_drop.index.to_list()
df_final_pa = df_finalpa.drop(lista_remover, axis = 0)
df_final_pa.sample(10)
# Out:
#                                         antecedents               consequents  \
# 39                               PEIXE DE AGUA DOCE                      AGUA
# 239  AGUA, MARGARINA COM OU SEM SAL, CAFE COM LEITE                    ACUCAR
# 13                                             CAFE                      AGUA
# 163                            CAFE COM LEITE, CAFE  MARGARINA COM OU SEM SAL
# 26                         MARGARINA COM OU SEM SAL            CAFE COM LEITE
# 32                                             AGUA       FARINHA DE MANDIOCA
# 112                       ACUCAR, FRANGO EM PEDACOS                      AGUA
# 122                            ACUCAR, ARROZ BRANCO       FARINHA DE MANDIOCA
# 150                                     AGUA, ARROZ       FARINHA DE MANDIOCA
# 23                                     ARROZ BRANCO                      AGUA
#
#      antecedent support  consequent support   support  confidence      lift  \
# ...

# %%
#Salvando dataframe para São Paulo:
df_final_sp.to_csv('data/datasetfinalsp.csv',index=False)

# %%
#Salvando dataframe para Minas Gerais:
df_final_mg.to_csv('data/datasetfinalmg.csv',index=False)

# %%
#Salvando dataframe para Bahia:
df_final_ba.to_csv('data/datasetfinalba.csv',index=False)

# %%
#Salvando dataframe para o Rio Grande do Sul:
df_final_rs.to_csv('data/datasetfinalrs.csv',index=False)

# %%
#Salvando dataframe para Goiás:
df_final_go.to_csv('data/datasetfinalgo.csv',index=False)

# %%
#Salvando dataframe para o Pará:
df_final_pa.to_csv('data/datasetfinalpa.csv',index=False)

# %%
df_final_ba['antecedents'].value_counts()
# Out:
# CAFE                                                             8
# MARGARINA COM OU SEM SAL                                         7
# PAO DE SAL                                                       7
# PAO FRANCES                                                      6
# CUSCUZ                                                           6
# AGUA, PAO FRANCES                                                6
# AGUA, CAFE                                                       5
# AGUA, MARGARINA COM OU SEM SAL                                   5
# ACUCAR                                                           5
# FARINHA DE MANDIOCA                                              5
# CAFE COM LEITE                                                   5
# ARROZ, CAFE                                                      5
# ACUCAR, ARROZ                                                    4
# AGUA, PAO DE SAL                                                 4
# ...
